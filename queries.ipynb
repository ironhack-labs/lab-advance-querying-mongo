# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient()
db = client.companies

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
babelgum = db.companies.find({"name" : "Babelgum"})
for e in babelgum:
    print(e["name"])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
empleados=db.companies.find({'number_of_employees':{'$gte':5000}}).sort([("number_of_employees", -1)]).limit(20)

for e in empleados:
    print(e["name"],e['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000
# Sony 180500
# LG 177000
# Ford 171000
# Boeing 160000
# Digital Equipment Corporation 140000
# Nokia 125000
# MItsubishi Electric 107000
# MItsubishi Electric 107000
# Comcast 100000
# Bertelsmann 100000

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
founded_year= db.companies.find({"founded_year": {"$gte": 2000, "$lte": 2005}})
for e in founded_year:
    print(e["name"],e["founded_year"])
# Out:
# TechnologyGuide 2001
# Wetpaint 2005
# Zoho 2005
# Digg 2004
# Facebook 2004
# Omnidrive 2005
# Gizmoz 2003
# Helio 2005
# AllofMP3 2000
# StumbleUpon 2002
# Plaxo 2002
# Technorati 2002
# AddThis 2004
# Veoh 2004
# Jingle Networks 2005
# Meetup 2002
# LifeLock 2005
# Wesabe 2005
# Jangl SMS 2005
# SmugMug 2002
# Jajah 2005
# Skype 2003
# YouTube 2005
# Pando Networks 2004
# Ikan 2003
# delicious 2003
# Topix 2002
# Jobster 2004
# Revision3 2005
# AllPeers 2004
# iSkoot 2005
# Steorn 2000
# iContact 2003
# MeeVee 2000
# blinkx 2004
# ClipBlast! 2005
# Zlio 2005
# Yelp 2004
# Coghead 2003
# Farecast 2003
# Dailymotion 2005
# KickApps 2004
# RockYou 2005
# Instructables 2005
# Netvibes 2005
# Swivel 2005
# Slide 2005
# Bebo 2005
# Flickr 2004
# TripHub 2005
# FeedBurner 2004
# Dogster 2004
# PBworks 2005
# Sway 2004
# CornerWorld 2002
# adBrite 2003
# Loomia 2004
# Meebo 2005
# Newsvine 2005
# LinkedIn 2003
# Jamendo 2005
# Box 2005
# iLike 2002
# Conduit 2005
# Kaboodle 2005
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
bla= db.companies.find({"$and":[{"founded_year":{"$lte": 2010}},{"ipo.valuation_amount":{"$gte": 100000000}}]})
for e in bla:
    print(e["name"],e["ipo"])
# Out:
# Facebook {'pub_month': 5, 'valuation_amount': 104000000000, 'stock_symbol': 'NASDAQ:FB', 'pub_day': 18, 'valuation_currency_code': 'USD', 'pub_year': 2012}
# Twitter {'pub_month': 11, 'valuation_amount': 18100000000, 'stock_symbol': 'NYSE:TWTR', 'pub_day': 7, 'valuation_currency_code': 'USD', 'pub_year': 2013}
# Yelp {'pub_month': 3, 'valuation_amount': 1300000000, 'stock_symbol': 'NYSE:YELP', 'pub_day': 2, 'valuation_currency_code': 'USD', 'pub_year': 2012}
# LinkedIn {'pub_month': 7, 'valuation_amount': 9310000000, 'stock_symbol': 'NYSE:LNKD', 'pub_day': 20, 'valuation_currency_code': 'USD', 'pub_year': 2011}
# Amazon {'pub_month': 5, 'valuation_amount': 100000000000, 'stock_symbol': 'NASDAQ:AMZN', 'pub_day': None, 'valuation_currency_code': 'USD', 'pub_year': 1997}
# Brightcove {'pub_month': 2, 'valuation_amount': 290000000, 'stock_symbol': 'NASDAQ:BCOV', 'pub_day': 17, 'valuation_currency_code': 'USD', 'pub_year': 2012}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
bla = db.companies.find({"$and":[{'number_of_employees':{"$lte": 1000}},{"founded_year":{"$lte": 2005}}]}).limit(10).sort([("number_of_employees", -1)])
for e in bla:
    print(e["name"])
# Out:
# Akamai Technologies
# Omniture
# Yodle
# Sonus Networks
# Telenav
# Antal International
# SK Net Service Company Ltd
# Gumtree
# FANUC Robotics America
# OC'LIANE

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
bla=db.companies.find({"partners":{"$exists": False}})
for e in bla:
    print(e["name"])

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
bla=db.companies.find({"category_code":{"$eq":None}})
for e in bla:
    print(e["name"])
# Out:
# Snimmer
# Drigg
# MMDAYS
# Collective
# KoolIM
# Level9 Media
# VidKing
# SpaceTime
# Touch Clarity
# Inside Group
# Repeater Store
# Tapesh
# iPersians
# NewPersia
# Pyra Labs
# Feedmap
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Picturehouse
# Covalent Technologies
# Epic Trip
# Telepost
# Fidelity
# Quirk
# Skyrove
# Leechblock
# My Success Gateway
# RealNames
# The Easynet Group
# NetNames
# Sniperoo
# JD Project
# ABC News
# Teoma Technologies
# cometro
# U-Cast
# TechJuicer
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Invitastic
# Windows Live Events
# News Futures
# Foresight Exchange
# Greenspun
# American Solutions
# Media Run
# Tonic Studios
# USLegalForms
# Livevault
# Vector Capital
# Neudesic
# TuneCircle
# Hotbar
# eWeb Productions
# FatPort
# Excilan SA
# SEO Toolset
# ClarityBlue
# Reuters
# Guru
# Paxfire
# Digital-Telepathy
# Pidgin Technologies
# Time Lending California
# Gazprom-Media
# reQall
# Fon11
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %% [markdown]
# Todas las empresas que tienen al menos 100 empleados pero menos de 1000. Recuperar sólo el nombre y el número de campos de empleados

# %%
bla= db.companies.find({"number_of_employees": {"$gte": 100, "$lte": 1000}})
for e in bla:
    print(e["name"],e["number_of_employees"])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Box 950
# Conduit 215
# Redfin 100
# oDesk 120
# Simply Hired 100
# PhotoBox 600
# Spreadshirt 230
# Bazaarvoice 600
# spigit 120
# PowerReviews 120
# hi5 100
# Tagged 162
# PayScale 130
# Truphone 450
# Brightcove 220
# Hightail 200
# Nimbuzz 140
# IMVU 150
# INgage Networks 100
# Akamai Technologies 1000
# Dropbox 350
# MobiTV 300
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# MySpace 800
# ZoomInfo 800
# Zango 225
# Trulia 500
# TubeMogul 230
# TechTarget 600
# Sportsline 264
# OpenTable 550
# Espotting 250
# Adknowledge 300
# airG 180
# ChannelAdvisor 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# mig33 100
# Mozilla 800
# Kaltura 160
# Zillow 600
# Moz 130
# Zimbra 200
# Wamba 120
# Fon 100
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# uTest 120
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
bla= db.companies.find().sort([("ipo.valuation_amount", 1)]).limit(20)
for e in bla:
    print(e["name"])
# Out:
# AdventNet
# TechnologyGuide
# Snimmer
# Wetpaint
# Zoho
# Digg
# Omnidrive
# Postini
# Geni
# Flektor
# Fox Interactive Media
# Gizmoz
# Helio
# AllofMP3
# Drigg
# StumbleUpon
# Scribd
# Slacker
# Lala
# eBay

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
bla= db.companies.find().sort([("number_of_employees", -1)]).limit(10)
for e in bla:
    print(e["name"],e["number_of_employees"])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
bla= db.companies.find({"founded_month": {"$gte": 4, "$lte": 6}}).limit(1000)
for e in bla:
    print(e["name"],e["founded_month"])
# Out:
# Postini 6
# Geni 6
# Fox Interactive Media 6
# AllofMP3 6
# Technorati 6
# OpenX 5
# Sparter 6
# blogTV 5
# Livestream 5
# GrandCentral 4
# Topix 6
# Pownce 6
# Revision3 4
# Spock 4
# iSkoot 4
# Mashery 5
# Coghead 5
# TripHub 6
# TVtrip 6
# PBworks 6
# WatZatSong 6
# LinkedIn 5
# Carbonite 5
# Seesmic 6
# Hotelicopter 6
# MyPublicInfo 5
# Checkster 4
# Bazaarvoice 5
# spigit 6
# LiveWorld 4
# Respectance 6
# Kiptronic 5
# Vuze 5
# DOmedia 5
# PodTech 5
# PayScale 5
# Nimbuzz 5
# MeeMix 6
# Alstrasoft 6
# AOL 5
# Webkinz 4
# Zwinky 6
# ActiveWorlds 6
# Sulake 5
# Pickle 6
# HireAHelper 5
# Dropbox 6
# TimeBridge 5
# TokBox 5
# DanceJam 4
# Inneractive 5
# EventVue 5
# Socialthing 5
# Filtrbox 4
# Cloudant 5
# Doostang 6
# TechCrunch 6
# Vlingo 6
# Alibaba 6
# Trulia 5
# Yeigo 6
# Shopzilla 6
# Seedcamp 5
# Webshots 6
# LimeLife 6
# Yap 5
# BlogSigs 5
# BBE 4
# Fotolog 5
# Contrastream 5
# Collagr 6
# Ooyala 4
# Daylife 4
# CrowdSpirit 4
# FAROO 4
# AgentMatch 6
# ElephantDrive 4
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
bla = db.companies.find({'$and':[{'founded_year':{'$lt': 2000}},{'acquisition.price_amount':{'$gt': 10000000}}]})
for e in bla:
    print(e["name"])
# Out:
# Postini
# SideStep
# Recipezaar
# PayPal
# Snapfish
# Neopets
# Sun Microsystems
# Zappos
# Alibaba
# Sabre
# Lastminute
# Sportsline
# Digitas
# Webshots
# MIVA
# iVillage
# PriceGrabber
# LinkShare
# Kaboose
# Fastclick
# Eloqua
# Omniture
# Interwoven
# HowStuffWorks
# RealAge
# Match
# Xdrive
# Alexa
# Offermatica
# ioko
# MyNewPlace
# DoubleClick
# Danger
# Direct Hit
# BEA Systems
# Napster
# SafeNet
# LowerMyBills
# Various
# aQuantive
# PeopleSupport
# Wedding Channel
# iCrossing
# Responsys
# Homestead Technologies
# Phoenix Technologies
# Macromedia
# GlobalEnglish
# PGP Corporation
# Iomega
# BizRate
# MessageLabs
# Gracenote
# Razorfish
# Sonic Solutions
# Siebel Systems
# Aprimo
# Opsware
# Netscape
# Vignette
# Blue Coat Systems
# Ars Technica
# LSI
# VMware
# OpenAir
# mindSHIFT Technologies
# InsureMe
# SwapDrive
# Marvel Entertainment
# CyberCoders
# Channel Intelligence
# Q-go
# Xerox
# Speedera Networks
# eBaum's World
# Audible
# Extend Media
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
bla= db.companies.find({'founded_year':{'$lt':2015}}).sort([('acquisition.price_amount', -1)]).limit(100)
for e in bla:
    print(e["name"],e['acquisition'])
# Out:
# BEA Systems {'source_description': 'Oracle to Acquire BEA Systems', 'acquired_day': 16, 'source_url': 'http://www.oracle.com/corporate/press/2008_jan/bea.html', 'price_currency_code': 'USD', 'acquiring_company': {'name': 'Oracle Corporation', 'permalink': 'oracle'}, 'acquired_year': 2008, 'price_amount': 8500000000, 'term_code': None, 'acquired_month': 1}
# Navteq {'source_description': 'Press Release', 'acquired_day': 10, 'source_url': 'http://www.businessweek.com/stories/2007-10-01/nokia-to-pay-8-dot-1-billion-for-navteqbusinessweek-business-news-stock-market-and-financial-advice', 'price_currency_code': 'USD', 'acquiring_company': {'name': 'Nokia', 'permalink': 'nokia'}, 'acquired_year': 2008, 'price_amount': 8100000000, 'term_code': None, 'acquired_month': 7}
# ...

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
bla= db.companies.find({"founded_year":{"$ne": None}}).sort([("founded_year", 1)]).limit(100)
for e in bla:
    print(e["name"],e['founded_year'])
# Out:
# Alstrasoft 1800
# SmallWorlds 1800
# US Army 1800
# DuPont 1802
# McKesson 1833
# Bachmann Industries 1833
# Bertelsmann 1835
# Accuity 1836
# CENTRA 1839
# WeGame 1840
# VideoSurf 1840
# VideoSurf 1840
# The Economist Group 1843
# Pearson 1844
# Associated Press 1846
# Beloit College 1846
# Siemens 1847
# Stiefel 1847
# Pfizer 1848
# Nykredit Realkredit 1851
# Corning 1851
# Louis Vuitton 1854
# Leucadia National 1854
# The McClatchy Company 1857
# University of Washington 1861
# Athenix 1863
# Nokia 1865
# Cornell University 1865
# Millage, Inc 1867
# Scotts Miracle-Gro 1868
# La Nacion 1870
# Chevron 1879
# SingTel 1879
# Elsevier 1880
# University of Southern California 1880
# Los Angeles Times Media Group 1881
# Financial Models Co 1883
# Telenor 1885
# Bristol-Myers Squibb 1887
# National Geographic 1888
# Financial Times 1888
# McGraw-Hill Companies 1888
# Nintendo 1889
# Wall Street Journal 1889
# General Electric 1890
# Teliasonera 1890
# Harris 1890
# Cision 1892
# ...

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
bla= db.companies.find({"founded_day":{"$lte": 7}}).sort([('acquisition.price_amount', 1)]).limit(10)
for e in bla:
    print(e["name"],e['founded_day'])
# Out:
# Facebook 1
# Omnidrive 1
# Geni 1
# Fox Interactive Media 1
# Gizmoz 1
# AllofMP3 1
# eBay 1
# Joost 1
# Babelgum 1
# Yahoo! 1

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
bla = db.companies.find({'$and':[{'category_code':'web'},{'number_of_employees':{'$gt': 4000}}]}).sort('number_of_employees',-1)
for e in bla:
    print(e["name"],e['number_of_employees'])
# Out:
# Experian 15500
# eBay 15000
# Yahoo! 13600
# Rakuten 10000
# Los Angeles Times Media Group 10000
# Groupon 10000
# Webkinz 8657
# AOL 8000
# Expedia 4400

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
bla = db.companies.find({'$and':[{'acquisition.price_currency_code':'EUR'},{'acquisition.price_amount':{'$gt': 10000000}}]}).sort('number_of_employees',-1)
for e in bla:
    print(e["name"])
# Out:
# Tuenti Technologies
# Webedia
# ZYB
# Apertio
# Greenfield Online
# Wayfinder
# BioMed Central

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
bla=db.companies.find({'founded_month':{'$lt':7}},{'name':1,'acquisition':1,'_id':0}).limit(10)
# Out:
# Facebook
# Postini
# Geni
# Fox Interactive Media
# Gizmoz
# Helio
# AllofMP3
# Twitter
# StumbleUpon
# Babelgum

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
bla=db.companies.find({'founded_year':{'$gt':1999, '$lt':2011}, 'acquisition.acquired_year':{'$gt':2010}},{'name':1,'_id':0})
for e in bla:
    print(e["name"])
# Out:
# Wetpaint
# Digg
# Geni
# Kyte
# Jingle Networks
# blogTV
# delicious
# Revision3
# iContact
# Mashery
# Dailymotion
# KickApps
# Instructables
# Netvibes
# Dogster
# adBrite
# Meebo
# Seesmic
# Zvents
# Oodle
# Flixster
# IceRocket
# hi5
# Indeed
# Grockit
# Zenfolio
# Wishpot
# Retrevo
# SelectMinds
# Flock
# TimeBridge
# TokBox
# Six Apart
# MySpace
# Doostang
# Docstoc
# Vlingo
# sezmi
# Greystripe
# LocaModa
# Thumbplay
# OMGPOP
# Daylife
# Behance
# Attributor
# WooMe
# Viewdle
# Mixx
# TripIt
# OneRiot
# Tumri
# Clickable
# GamerDNA
# Xobni
# Sermo
# Worklight
# PlaySpan
# Zimbra
# earthmine
# Whiskey Media
# VoodooVox
# CondoDomain
# Uptake
# AdReady
# The Climate Corporation
# Tumblr
# JackBe
# EchoSign
# Rollbase
# Marakana
# Peer39
# Vitrue
# Pelago
# MerchantCircle
# Loopt
# Bloglines
# Mogreet
# UpNext
# TrustedID
# Sendori
# Kewego
# SocialPicks
# Shipwire
# Smilebox
# Kosmix
# Goodreads
# Qik
# KAYAK
# Scrapblog
# Meraki
# Jobfox
# Outspark
# Livemocha
# Mpayy
# ...
