# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
import pymongo

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
data={'name':'Babelgum'}
print(data['name'])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
data2 = db.companies.find ({ 'number_of_employees': { '$gt': 5000 } }).limit(20).sort('number_of_employees')
for x in data2:
    print(x['name'], x['number_of_employees'])
# Out:
# Nintendo 5080
# Hexaware Technologies 5200
# Facebook 5299
# OpenText 5300
# LSI 5400
# CPM Braxis 5400
# Microchip Technologies 5500
# Mediaset 5729
# Mindray Medical International 5763
# Baidu 6000
# Dentsu 6000
# Tata Communications 6000
# Atmel 6000
# Acxiom 6200
# Acxiom 6200
# SRA International 6400
# Moody's 6800
# ManTech 7000
# Adobe Systems 7173
# Broadcom 7400

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
data3 = db.companies.find( { '$and': [ { 'founded_year': { '$gt': 2000 } }, { 'founded_year': { '$lt': 2005 } }] } )
for y in data3:
    print(y['name'], y['founded_year'])
# Out:
# TechnologyGuide 2001
# Digg 2004
# Gizmoz 2003
# StumbleUpon 2002
# Plaxo 2002
# Facebook 2004
# Technorati 2002
# AddThis 2004
# Meetup 2002
# SmugMug 2002
# Veoh 2004
# Pando Networks 2004
# Ikan 2003
# AllPeers 2004
# Skype 2003
# delicious 2003
# Topix 2002
# Jobster 2004
# iContact 2003
# Coghead 2003
# blinkx 2004
# Yelp 2004
# Farecast 2003
# KickApps 2004
# Flickr 2004
# FeedBurner 2004
# Dogster 2004
# Sway 2004
# CornerWorld 2002
# adBrite 2003
# Loomia 2004
# Wink 2004
# Redfin 2004
# Techmeme 2004
# iLike 2002
# Oodle 2004
# Eventful 2004
# LinkedIn 2003
# Simply Hired 2004
# ooma 2004
# stylediary 2004
# MyPublicInfo 2004
# Vast 2001
# Spreadshirt 2002
# IceRocket 2004
# Socialtext 2002
# Ohloh 2004
# hi5 2003
# Tagged 2004
# Cerado 2002
# introNetworks 2003
# Indeed 2004
# PeerMe 2004
# eBuddy 2003
# Crackle 2004
# Clipmarks 2003
# Hightail 2004
# TalkPlus 2004
# Brightcove 2004
# Vudu 2004
# Kaneva 2004
# IMVU 2004
# Userplane 2001
# Dubit 2003
# Millsberry 2004
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
data4 = db.companies.find( { '$and': [ { 'ipo.valuation_amount': { '$gt': 100000000 } }, { 'founded_year': { '$lt': 2010 } }] } )
for a in data4:
    print(a['name'], a['ipo'])
# Out:
# Twitter {'pub_year': 2013, 'stock_symbol': 'NYSE:TWTR', 'valuation_amount': 18100000000, 'pub_day': 7, 'valuation_currency_code': 'USD', 'pub_month': 11}
# Facebook {'pub_year': 2012, 'stock_symbol': 'NASDAQ:FB', 'valuation_amount': 104000000000, 'pub_day': 18, 'valuation_currency_code': 'USD', 'pub_month': 5}
# Yelp {'pub_year': 2012, 'stock_symbol': 'NYSE:YELP', 'valuation_amount': 1300000000, 'pub_day': 2, 'valuation_currency_code': 'USD', 'pub_month': 3}
# LinkedIn {'pub_year': 2011, 'stock_symbol': 'NYSE:LNKD', 'valuation_amount': 9310000000, 'pub_day': 20, 'valuation_currency_code': 'USD', 'pub_month': 7}
# Brightcove {'pub_year': 2012, 'stock_symbol': 'NASDAQ:BCOV', 'valuation_amount': 290000000, 'pub_day': 17, 'valuation_currency_code': 'USD', 'pub_month': 2}
# Amazon {'pub_year': 1997, 'stock_symbol': 'NASDAQ:AMZN', 'valuation_amount': 100000000000, 'pub_day': None, 'valuation_currency_code': 'USD', 'pub_month': 5}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
data5 = db.companies.find( { '$and': [ { 'number_of_employees': { '$lt': 1000 } }, { 'founded_year': { '$lt': 2005 } }] } ).limit(10).sort('number_of_employees',-1)
for b in data5:
    print(b['name'], b['number_of_employees'])
# Out:
# Infinera Corporation 974
# NorthPoint Communications Group 948
# 888 Holdings 931
# Forrester Research 903
# SonicWALL 900
# Webmetrics 900
# Cornerstone OnDemand 881
# Yelp 800
# MySpace 800
# ZoomInfo 800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
data6 = db.companies.find( { 'partners': { '$exists': False } })
for c in data6:
    print(c['name'])

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
data7 = db.companies.find( { 'category_code': None } )
for d in data7:
    print(d['name'])
# Out:
# Collective
# Drigg
# MMDAYS
# Snimmer
# KoolIM
# Level9 Media
# VidKing
# SpaceTime
# Touch Clarity
# Inside Group
# Repeater Store
# iPersians
# Tapesh
# NewPersia
# Pyra Labs
# Feedmap
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Covalent Technologies
# Picturehouse
# Epic Trip
# Telepost
# Fidelity
# Leechblock
# Quirk
# Skyrove
# My Success Gateway
# The Easynet Group
# RealNames
# NetNames
# Sniperoo
# JD Project
# ABC News
# Teoma Technologies
# cometro
# U-Cast
# TechJuicer
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Invitastic
# Windows Live Events
# News Futures
# Foresight Exchange
# Greenspun
# American Solutions
# Media Run
# Tonic Studios
# USLegalForms
# Livevault
# Vector Capital
# Neudesic
# TuneCircle
# eWeb Productions
# Hotbar
# FatPort
# Excilan SA
# SEO Toolset
# ClarityBlue
# Reuters
# Guru
# Paxfire
# Digital-Telepathy
# Pidgin Technologies
# Time Lending California
# Gazprom-Media
# reQall
# Fon11
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
data8 = db.companies.find( { '$and': [ { 'number_of_employees': { '$gt': 100 } }, { 'number_of_employees': { '$lt': 1000 } }] } )
for f in data8:
    print(f['name'], f['number_of_employees'])
# Out:
# AdventNet 600
# OpenX 305
# AddThis 120
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Conduit 215
# Box 950
# oDesk 120
# PhotoBox 600
# Spreadshirt 230
# spigit 120
# Bazaarvoice 600
# PowerReviews 120
# Tagged 162
# PayScale 130
# Truphone 450
# Nimbuzz 140
# Hightail 200
# Brightcove 220
# IMVU 150
# MobiTV 300
# Dropbox 350
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# MySpace 800
# Zango 225
# ZoomInfo 800
# Trulia 500
# TechTarget 600
# TubeMogul 230
# Sportsline 264
# Espotting 250
# OpenTable 550
# airG 180
# Adknowledge 300
# ChannelAdvisor 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# Mozilla 800
# Kaltura 160
# Zillow 600
# Moz 130
# Wamba 120
# Zimbra 200
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# Payoneer 200
# uTest 120
# Shopatron 166
# Wix 400
# tyntec 150
# Gigya 230
# Alipay 500
# MyBuys 120
# Zecco 110
# Vobile 120
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
data9 = db.companies.find().sort('ipo.valuation_amount', -1).limit(20)
for g in data9:
    print(g['name'])
# Out:
# GREE
# Facebook
# Amazon
# Twitter
# Groupon
# Tencent
# Western Digital
# LinkedIn
# BMC Software
# Rackspace
# Baidu
# TripAdvisor
# HomeAway
# Zillow
# Nielsen
# Yelp
# Chegg
# Chegg
# RPX Corporation
# Higher One

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
data10 = db.companies.find().sort('number_of_employees', -1).limit(10)
for h in data10:
    print(h['name'], h['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
data11 = db.companies.find({ 'founded_month': { '$gte': 7 }}).limit(1000)
for i in data11:
    print(i['name'], i['founded_month'])
# Out:
# TechnologyGuide 10
# Wetpaint 10
# Zoho 9
# Digg 10
# Omnidrive 11
# Joost 10
# Plaxo 11
# eBay 9
# Powerset 10
# Kyte 12
# Jingle Networks 9
# Thoof 12
# Wesabe 12
# SmugMug 11
# LifeLock 8
# Pando Networks 7
# Ikan 12
# AllPeers 8
# Skype 8
# delicious 9
# Wize 8
# SellABand 8
# iContact 7
# Zlio 11
# Jaiku 7
# MeeVee 7
# Fleck 11
# blinkx 12
# SideStep 11
# Yelp 7
# Yapta 7
# RockYou 11
# Instructables 8
# Swivel 12
# Netvibes 9
# Slide 8
# CrowdVine 8
# TheFind 10
# Sway 12
# CornerWorld 9
# FlickIM 12
# Terabitz 7
# Kaboodle 10
# Wink 8
# Go2Web20 9
# GigaOM 7
# Google 9
# Redfin 10
# Techmeme 10
# Gumiyo 11
# stylediary 8
# Ujogo 7
# Recipezaar 9
# Piczo 11
# Cyworld 7
# Socialtext 12
# ConnectMeAnywhere 9
# Clipperz 11
# Nintendo 9
# hi5 12
# Tagged 10
# Cerado 7
# ONEsite 9
# Indeed 11
# Jaxtr 10
# Wallhogs 8
# eBuddy 9
# Grockit 12
# Relationals 7
# JumpBox 7
# LongJump 7
# Phonezoo 11
# Wishpot 11
# Boonex 7
# Forbes 8
# IntenseDebate 12
# Rebtel 7
# Adobe Systems 12
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
#no lo conseguí

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
data13 = db.companies.find( { '$and': [ { 'founded_year': { '$lt': 2000 } }, { 'acquisition.price_amount': { '$gt': 10000000 } }] } )
for g in data13:
    print(g['name'])
# Out:
# Postini
# SideStep
# Recipezaar
# PayPal
# Snapfish
# Neopets
# Sun Microsystems
# Zappos
# Alibaba
# Sabre
# Lastminute
# Sportsline
# Webshots
# Digitas
# MIVA
# iVillage
# PriceGrabber
# LinkShare
# Kaboose
# Fastclick
# Eloqua
# Interwoven
# Omniture
# HowStuffWorks
# RealAge
# Match
# Xdrive
# Alexa
# Offermatica
# ioko
# MyNewPlace
# DoubleClick
# Danger
# Direct Hit
# BEA Systems
# Napster
# SafeNet
# LowerMyBills
# Various
# aQuantive
# PeopleSupport
# Wedding Channel
# iCrossing
# Homestead Technologies
# Responsys
# Phoenix Technologies
# GlobalEnglish
# Macromedia
# PGP Corporation
# Iomega
# BizRate
# MessageLabs
# Gracenote
# Razorfish
# Sonic Solutions
# Siebel Systems
# Aprimo
# Opsware
# Netscape
# Vignette
# Blue Coat Systems
# Ars Technica
# LSI
# VMware
# OpenAir
# mindSHIFT Technologies
# InsureMe
# SwapDrive
# Marvel Entertainment
# CyberCoders
# Channel Intelligence
# Q-go
# Xerox
# Speedera Networks
# eBaum's World
# Audible
# Extend Media
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
data14 = db.companies.find( { 'acquisition.acquired_year': { '$gt': 2015 } }).sort('acquisition.price_amount')
for j in data14:
    print(j['name'])

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
data15 = db.companies.find().sort('founded_year', -1).limit(10)
for l in data15:
    print(l['name'], l['founded_year'])
# Out:
# Fixya 2013
# Wamba 2013
# Advaliant 2013
# Fluc 2013
# iBazar 2013
# Gimigo 2013
# SEOGroup 2013
# Clowdy 2013
# WhosCall 2013
# Pikk 2013

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
data16 = db.companies.find({ 'founded_day': { '$lte': 7 }}).sort('acquisition.price_amount', -1).limit(10)
for k in data16:
    print(k['name'], k['founded_day'])
# Out:
# Netscape 4
# PayPal 1
# Zappos 1
# Alibaba 1
# Postini 2
# Danger 1
# Clearwell Systems 6
# PrimeSense 1
# Amobee 1
# BlueLithium 1

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
data17 = db.companies.find({ '$and': [{'category_code':'web'},{'number_of_employees': { '$gt': 4000 }}]}).limit(10).sort('number_of_employees')
for m in data17:
    print(m['name'], m['founded_day'])
# Out:
# Expedia None
# AOL 24
# Webkinz 25
# Rakuten 7
# Los Angeles Times Media Group 4
# Groupon 11
# Yahoo! 1
# eBay 1
# Experian None

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
data18 = db.companies.find({'$and': [{'acquisition.price_currency_code':'EUR'}, {'acquisition.price_amount': {'$gt':10000000}}]}).limit(10)
for n in data18:
    print(n['name'])
# Out:
# ZYB
# Apertio
# Greenfield Online
# Webedia
# Wayfinder
# Tuenti Technologies
# BioMed Central

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
data19 = db.companies.find({'$and': [{'acquisition.acquired_month': {'$lte':3}}, {'acquisition': {'$exists': True}}]}).limit(10)
for o in data19:
    print(o['name'], o['acquisition'])
# Out:
# Kyte {'acquiring_company': {'permalink': 'kit-digital', 'name': 'KIT digital'}, 'price_amount': None, 'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/', 'price_currency_code': 'USD', 'term_code': None, 'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million', 'acquired_year': 2011, 'acquired_day': 31, 'acquired_month': 1}
# NetRatings {'acquiring_company': {'permalink': 'nielsen', 'name': 'Nielsen'}, 'price_amount': 327000000, 'source_url': 'http://login.vnuemedia.com/hr/login/login_subscribe.jsp?id=0oqDem1gYIfIclz9i2%2Ffqj5NxCp2AC5DPbVnyT2da8GyV2mXjasabE128n69OrmcAh52%2FGE3pSG%2F%0AEKRYD9vh9EhrJrxukmUzh532fSMTZXL42gwPB80UWVtF1NwJ5UZSM%2BCkLU1mpYBoHFgiH%2Fi0f6Ax%0A9yMIVxt47t%2BHamhEQ0nkOEK24L', 'price_currency_code': 'USD', 'term_code': 'cash', 'source_description': 'Nielsen buys rest of NetRatings', 'acquired_year': 2007, 'acquired_day': None, 'acquired_month': 2}
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
data20 = db.companies.find({'$and': [{'founded_year': {'$gte':2000} }, {'founded_year': {'$lte':2010} }, {'acquisition.acquired_year': {'$gt':2011} }]}).limit(10) 
for p in data20:
    print(p['name'])
# Out:
# Wetpaint
# Digg
# Geni
# blogTV
# Revision3
# iContact
# Mashery
# Dailymotion
# KickApps
# Netvibes
