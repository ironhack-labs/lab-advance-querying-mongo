# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
data={'name':'Babelgum'}
print(data['name'])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
cursor=db.companies.find ({'number_of_employees': {'$gt':5000}}).limit(20).sort('number_of_employees')
for e in cursor:
    print(e['name'],e['number_of_employees'] )
# Out:
# Nintendo 5080
# Hexaware Technologies 5200
# Facebook 5299
# OpenText 5300
# LSI 5400
# CPM Braxis 5400
# Microchip Technologies 5500
# Mediaset 5729
# Mindray Medical International 5763
# Baidu 6000
# Dentsu 6000
# Tata Communications 6000
# Atmel 6000
# Acxiom 6200
# Acxiom 6200
# SRA International 6400
# Moody's 6800
# ManTech 7000
# Adobe Systems 7173
# Broadcom 7400

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
founded=db.companies.find({'$and':[{'founded_year': {'$gte':2000}},{'founded_year': {'$lte':2005}}]})
for i in founded:
    print(i['name'],i['founded_year'])
# Out:
# Wetpaint 2005
# Zoho 2005
# Digg 2004
# Omnidrive 2005
# StumbleUpon 2002
# Gizmoz 2003
# Facebook 2004
# Helio 2005
# Plaxo 2002
# AddThis 2004
# Technorati 2002
# Veoh 2004
# Jingle Networks 2005
# Meetup 2002
# LifeLock 2005
# Jangl SMS 2005
# SmugMug 2002
# Wesabe 2005
# YouTube 2005
# Skype 2003
# Pando Networks 2004
# Jajah 2005
# Ikan 2003
# Topix 2002
# delicious 2003
# Jobster 2004
# AllPeers 2004
# Revision3 2005
# iSkoot 2005
# AllofMP3 2000
# MeeVee 2000
# blinkx 2004
# iContact 2003
# Steorn 2000
# ClipBlast! 2005
# Zlio 2005
# Yelp 2004
# Coghead 2003
# Farecast 2003
# Dailymotion 2005
# KickApps 2004
# Instructables 2005
# Swivel 2005
# Netvibes 2005
# RockYou 2005
# Slide 2005
# Flickr 2004
# Bebo 2005
# TripHub 2005
# FeedBurner 2004
# Dogster 2004
# CornerWorld 2002
# adBrite 2003
# PBworks 2005
# Sway 2004
# Meebo 2005
# Loomia 2004
# Newsvine 2005
# Jamendo 2005
# iLike 2002
# Box 2005
# LinkedIn 2003
# Conduit 2005
# Wink 2004
# TechnologyGuide 2001
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cur2=db.companies.find({'$and':[{'ipo.valuation_amount': {'$gt':100000000}},{'founded_year':{'$lt':2010}}]})
for i in cur2:
   print(i['name'],i['ipo'])
# Out:
# Facebook {'valuation_amount': 104000000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 5, 'pub_day': 18, 'stock_symbol': 'NASDAQ:FB'}
# Twitter {'valuation_amount': 18100000000, 'valuation_currency_code': 'USD', 'pub_year': 2013, 'pub_month': 11, 'pub_day': 7, 'stock_symbol': 'NYSE:TWTR'}
# Yelp {'valuation_amount': 1300000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 3, 'pub_day': 2, 'stock_symbol': 'NYSE:YELP'}
# LinkedIn {'valuation_amount': 9310000000, 'valuation_currency_code': 'USD', 'pub_year': 2011, 'pub_month': 7, 'pub_day': 20, 'stock_symbol': 'NYSE:LNKD'}
# Amazon {'valuation_amount': 100000000000, 'valuation_currency_code': 'USD', 'pub_year': 1997, 'pub_month': 5, 'pub_day': None, 'stock_symbol': 'NASDAQ:AMZN'}
# Brightcove {'valuation_amount': 290000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 2, 'pub_day': 17, 'stock_symbol': 'NASDAQ:BCOV'}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cur3=db.companies.find({'$and':[{'number_of_employees': {'$lt':1000}},{'founded_year':{'$lt':2005}}]}).limit(10).sort('number_of_employees',-1)
for e in cur3:
    print(e['name'],e['number_of_employees'] )
# Out:
# Infinera Corporation 974
# NorthPoint Communications Group 948
# 888 Holdings 931
# Forrester Research 903
# SonicWALL 900
# Webmetrics 900
# Cornerstone OnDemand 881
# Yelp 800
# ZoomInfo 800
# MySpace 800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
cur4=db.companies.find({'partners':{'$exists':False}})
for i in cur4:
    print(i['name'])

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
cur5=db.companies.find({'category_code':{'$type':'null'}})
for i in cur5:
    print(i['name'])
# Out:
# Collective
# Snimmer
# KoolIM
# Level9 Media
# VidKing
# Drigg
# SpaceTime
# Touch Clarity
# MMDAYS
# Inside Group
# Repeater Store
# Tapesh
# iPersians
# NewPersia
# Feedmap
# Pyra Labs
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Picturehouse
# Covalent Technologies
# Telepost
# Fidelity
# Quirk
# Epic Trip
# Skyrove
# Leechblock
# My Success Gateway
# RealNames
# NetNames
# Sniperoo
# The Easynet Group
# JD Project
# ABC News
# Teoma Technologies
# cometro
# TechJuicer
# U-Cast
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Windows Live Events
# Invitastic
# News Futures
# Foresight Exchange
# Greenspun
# American Solutions
# Media Run
# Tonic Studios
# USLegalForms
# Livevault
# Vector Capital
# Neudesic
# TuneCircle
# Hotbar
# eWeb Productions
# Excilan SA
# FatPort
# SEO Toolset
# ClarityBlue
# Reuters
# Guru
# Paxfire
# Digital-Telepathy
# Pidgin Technologies
# Time Lending California
# Gazprom-Media
# reQall
# Fon11
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cur6=db.companies.find({'$and':[{'number_of_employees': {'$gte':100}},{'number_of_employees':{'$lt':1000}}]})
for i in cur6:
    print(i['name'],i['number_of_employees'])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Livestream 120
# Ustream 250
# Jajah 110
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Box 950
# Conduit 215
# Redfin 100
# oDesk 120
# Simply Hired 100
# PhotoBox 600
# Spreadshirt 230
# spigit 120
# PowerReviews 120
# Bazaarvoice 600
# hi5 100
# Tagged 162
# Truphone 450
# PayScale 130
# Brightcove 220
# Nimbuzz 140
# Hightail 200
# IMVU 150
# INgage Networks 100
# Dropbox 350
# MobiTV 300
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# ZoomInfo 800
# Zango 225
# MySpace 800
# Trulia 500
# TechTarget 600
# TubeMogul 230
# Sportsline 264
# OpenTable 550
# Espotting 250
# airG 180
# ChannelAdvisor 300
# Adknowledge 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# mig33 100
# Mozilla 800
# Kaltura 160
# Moz 130
# Zillow 600
# Zimbra 200
# Wamba 120
# Fon 100
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# uTest 120
# Payoneer 200
# Shopatron 166
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
cur7=db.companies.find().sort('ipo.valuation_amount',-1).limit(20)
for i in cur7:
    print(i['name'])
# Out:
# GREE
# Facebook
# Amazon
# Twitter
# Groupon
# Tencent
# Western Digital
# LinkedIn
# BMC Software
# Rackspace
# Baidu
# TripAdvisor
# HomeAway
# Zillow
# Nielsen
# Yelp
# Chegg
# Chegg
# RPX Corporation
# Higher One

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
cur8=db.companies.find().sort('number_of_employees',-1).limit(10)
for i in cur8:
    print(i['name'],i['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
cur9=db.companies.find({'founded_month':{'$gte':7}}).limit(1000)
for i in cur9:
    print(i['name'])
# Out:
# Wetpaint
# Zoho
# Digg
# Omnidrive
# Joost
# eBay
# Plaxo
# Powerset
# Kyte
# Thoof
# Jingle Networks
# LifeLock
# SmugMug
# Wesabe
# Skype
# Pando Networks
# Ikan
# delicious
# AllPeers
# Wize
# SellABand
# MeeVee
# blinkx
# iContact
# Zlio
# Jaiku
# Yelp
# Yapta
# Fleck
# Google
# SideStep
# Instructables
# Swivel
# Netvibes
# RockYou
# Slide
# CrowdVine
# TheFind
# CornerWorld
# Sway
# FlickIM
# Terabitz
# Wink
# Go2Web20
# GigaOM
# TechnologyGuide
# Redfin
# Kaboodle
# Techmeme
# Ujogo
# Recipezaar
# stylediary
# Gumiyo
# Piczo
# Cyworld
# Socialtext
# ConnectMeAnywhere
# Clipperz
# hi5
# Tagged
# Cerado
# Indeed
# ONEsite
# Jaxtr
# Wallhogs
# eBuddy
# Grockit
# Nintendo
# JumpBox
# Phonezoo
# Relationals
# LongJump
# Wishpot
# Adobe Systems
# Forbes
# Boonex
# Rebtel
# IntenseDebate
# Buxfer
# boo-box
# TextPayMe
# BillMonk
# WebbAlert
# Rocketboom
# The Walt Disney Company
# WallStrip
# IAC
# PayPal
# Nirvanix
# Mokitown
# Neopets
# KnockaTV
# Revver
# MindTouch
# ChaCha
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
cur11=db.companies.find({'$and':[{'founded_year': {'$lt':2000}},{'acquisition.price_amount':{'$gt':10000000}}]})
for i in cur11:
    print(i['name'])
# Out:
# Postini
# SideStep
# Recipezaar
# PayPal
# Snapfish
# Neopets
# Sun Microsystems
# Zappos
# Alibaba
# Sabre
# Lastminute
# Sportsline
# MIVA
# Webshots
# Digitas
# iVillage
# PriceGrabber
# LinkShare
# Kaboose
# Fastclick
# Eloqua
# Interwoven
# Omniture
# RealAge
# HowStuffWorks
# Match
# Xdrive
# Alexa
# Offermatica
# ioko
# MyNewPlace
# DoubleClick
# Danger
# Direct Hit
# BEA Systems
# Napster
# SafeNet
# LowerMyBills
# Various
# aQuantive
# PeopleSupport
# Wedding Channel
# iCrossing
# Responsys
# Homestead Technologies
# Phoenix Technologies
# Macromedia
# GlobalEnglish
# PGP Corporation
# Iomega
# BizRate
# MessageLabs
# Gracenote
# Razorfish
# Sonic Solutions
# Siebel Systems
# Aprimo
# Opsware
# Netscape
# Vignette
# Blue Coat Systems
# Ars Technica
# LSI
# VMware
# OpenAir
# mindSHIFT Technologies
# InsureMe
# SwapDrive
# Marvel Entertainment
# CyberCoders
# Channel Intelligence
# Q-go
# Xerox
# Speedera Networks
# eBaum's World
# Audible
# Extend Media
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
cur12=db.companies.find({'acquisition.acquired_year': {'$gt':2015}}).sort('acquisition.price_amount')
for i in cur12:
    print(i['name'],i['acquisition'])

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
cur13=db.companies.find().sort('founded_year',-1).limit(10)
for i in cur13:
    print(i['name'],i['founded_year'])
# Out:
# Fixya 2013
# Wamba 2013
# Advaliant 2013
# Fluc 2013
# iBazar 2013
# Gimigo 2013
# SEOGroup 2013
# Clowdy 2013
# WhosCall 2013
# Pikk 2013

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
cur13=db.companies.find({'founded_day':{'$lte':7}}).sort('acquisition.price_amount',-1).limit(10)
for i in cur13:
    print(i['name'])
# Out:
# Netscape
# PayPal
# Zappos
# Alibaba
# Postini
# Danger
# Clearwell Systems
# PrimeSense
# Amobee
# BlueLithium

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
cur14=db.companies.find({'$and':[{'category_code':'web'},{'number_of_employees':{'$gt':4000}}]}).sort('number_of_employees')
for i in cur14:
    print(i['name'])
# Out:
# Expedia
# AOL
# Webkinz
# Rakuten
# Los Angeles Times Media Group
# Groupon
# Yahoo!
# eBay
# Experian

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
cur15=db.companies.find({'$and':[{'acquisition.price_amount': {'$gt':10000000}},{'acquisition.price_currency_code':'EUR'}]}).limit(10)
for i in cur15:
    print(i['name'])
# Out:
# ZYB
# Apertio
# Greenfield Online
# Webedia
# Wayfinder
# Tuenti Technologies
# BioMed Central

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.
