# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
babelgum=db.companies.find({'name':'Babelgum'}, {'name':1,'_id':0})
print(list(babelgum))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
emp=db.companies.find({'number_of_employees':{'$gt':600}},{'name':1,'_id':0}).sort('number_of_employees',-1).limit(20)
print(list(emp))
# Out:
# [{'name': 'Siemens'}, {'name': 'IBM'}, {'name': 'Toyota'}, {'name': 'PayPal'}, {'name': 'Nippon Telegraph and Telephone Corporation'}, {'name': 'Samsung Electronics'}, {'name': 'Accenture'}, {'name': 'Tata Consultancy Services'}, {'name': 'Flextronics International'}, {'name': 'Safeway'}, {'name': 'Sony'}, {'name': 'LG'}, {'name': 'Ford'}, {'name': 'Boeing'}, {'name': 'Digital Equipment Corporation'}, {'name': 'Nokia'}, {'name': 'MItsubishi Electric'}, {'name': 'MItsubishi Electric'}, {'name': 'Comcast'}, {'name': 'Bertelsmann'}]

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
founded=db.companies.find({'founded_year':{'$gt':1999, '$lt':2006}},{'name':1,'founded_year':1,'_id':0})
print(list(founded))
# Out:
# [{'name': 'Wetpaint', 'founded_year': 2005}, {'name': 'Zoho', 'founded_year': 2005}, {'name': 'Omnidrive', 'founded_year': 2005}, {'name': 'Digg', 'founded_year': 2004}, {'name': 'StumbleUpon', 'founded_year': 2002}, {'name': 'Gizmoz', 'founded_year': 2003}, {'name': 'Helio', 'founded_year': 2005}, {'name': 'Facebook', 'founded_year': 2004}, {'name': 'Plaxo', 'founded_year': 2002}, {'name': 'Technorati', 'founded_year': 2002}, {'name': 'AddThis', 'founded_year': 2004}, {'name': 'Veoh', 'founded_year': 2004}, {'name': 'Jingle Networks', 'founded_year': 2005}, {'name': 'LifeLock', 'founded_year': 2005}, {'name': 'Wesabe', 'founded_year': 2005}, {'name': 'Jangl SMS', 'founded_year': 2005}, {'name': 'SmugMug', 'founded_year': 2002}, {'name': 'Meetup', 'founded_year': 2002}, {'name': 'Skype', 'founded_year': 2003}, {'name': 'YouTube', 'founded_year': 2005}, {'name': 'Pando Networks', 'founded_year': 2004}, {'name': 'Jajah', 'founded_year': 2005}, {'name': 'Ikan', 'founded_year': 2003}, {'
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
vf=db.companies.find({'ipo.valuation_amount':{'$gt':100000000},'founded_year':{'$lt':2010}},{'name':1,'ipo':1,'_id':0})
print(list(vf))
# Out:
# [{'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000, 'valuation_currency_code': 'USD', 'pub_year': 2013, 'pub_month': 11, 'pub_day': 7, 'stock_symbol': 'NYSE:TWTR'}}, {'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 5, 'pub_day': 18, 'stock_symbol': 'NASDAQ:FB'}}, {'name': 'Yelp', 'ipo': {'valuation_amount': 1300000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 3, 'pub_day': 2, 'stock_symbol': 'NYSE:YELP'}}, {'name': 'LinkedIn', 'ipo': {'valuation_amount': 9310000000, 'valuation_currency_code': 'USD', 'pub_year': 2011, 'pub_month': 7, 'pub_day': 20, 'stock_symbol': 'NYSE:LNKD'}}, {'name': 'Brightcove', 'ipo': {'valuation_amount': 290000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 2, 'pub_day': 17, 'stock_symbol': 'NASDAQ:BCOV'}}, {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000, 'valuation_currency_code': 'USD', 'pub_year': 1997, 'pub_mont
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
ef=db.companies.find({'number_of_employees':{'$lt':1000},'founded_year':{'$lt':2005}}).sort('number_of_employees',-1).limit(10)
print(list(ef))
# Out:
# [{'_id': ObjectId('52cdef7d4bab8bd675298933'), 'name': 'Infinera Corporation', 'permalink': 'infinera', 'crunchbase_url': 'http://www.crunchbase.com/company/infinera', 'homepage_url': 'http://www.infinera.com', 'blog_url': '', 'blog_feed_url': '', 'twitter_username': 'InfineraCorp', 'category_code': 'network_hosting', 'number_of_employees': 974, 'founded_year': 2000, 'founded_month': None, 'founded_day': None, 'deadpooled_year': None, 'deadpooled_month': None, 'deadpooled_day': None, 'deadpooled_url': None, 'tag_list': None, 'alias_list': 'Zepton Networks', 'email_address': '', 'phone_number': '408-572-5200', 'description': 'Optical Networking Systems', 'created_at': 'Tue Apr 29 19:43:09 UTC 2008', 'updated_at': 'Tue Jan 10 22:07:21 UTC 2012', 'overview': '<p>Infinera Corporation provides optical networking systems based on photonic integration technology in the United States. Its digital transport node (DTN) system utilizes the photonic integrated circuit (PIC) technology to enable 
# ...

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
no_part= db.companies.find({'partners':{'$exists':False}},{'name':1, '_id':0})
print(list(no_part))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
null_cat=db.companies.find({'category_code':{'$type': 10 }},{ 'name': 1, '_id': 0 })
print(list(null_cat))
# Out:
# [{'name': 'Collective'}, {'name': 'Snimmer'}, {'name': 'KoolIM'}, {'name': 'Level9 Media'}, {'name': 'VidKing'}, {'name': 'Drigg'}, {'name': 'SpaceTime'}, {'name': 'MMDAYS'}, {'name': 'Touch Clarity'}, {'name': 'Inside Group'}, {'name': 'Repeater Store'}, {'name': 'Tapesh'}, {'name': 'iPersians'}, {'name': 'NewPersia'}, {'name': 'Pyra Labs'}, {'name': 'Feedmap'}, {'name': 'NuvoMedia'}, {'name': 'Intwine'}, {'name': 'The Weinstein Company'}, {'name': 'ExecuNet'}, {'name': 'A1Vacations'}, {'name': 'TripHomes'}, {'name': 'Picturehouse'}, {'name': 'Covalent Technologies'}, {'name': 'Telepost'}, {'name': 'Fidelity'}, {'name': 'Quirk'}, {'name': 'Leechblock'}, {'name': 'Skyrove'}, {'name': 'Epic Trip'}, {'name': 'My Success Gateway'}, {'name': 'RealNames'}, {'name': 'The Easynet Group'}, {'name': 'NetNames'}, {'name': 'Sniperoo'}, {'name': 'ABC News'}, {'name': 'JD Project'}, {'name': 'Teoma Technologies'}, {'name': 'cometro'}, {'name': 'U-Cast'}, {'name': 'TechJuicer'}, {'name': 'Fnatic'}
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
emp2=db.companies.find({'number_of_employees':{'$gt':99, '$lt':1001}},{'name':1,'number_of_employees':1,'_id':0})
print(list(emp2))
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600}, {'name': 'AddThis', 'number_of_employees': 120}, {'name': 'OpenX', 'number_of_employees': 305}, {'name': 'LifeLock', 'number_of_employees': 644}, {'name': 'Livestream', 'number_of_employees': 120}, {'name': 'Jajah', 'number_of_employees': 110}, {'name': 'Ustream', 'number_of_employees': 250}, {'name': 'iContact', 'number_of_employees': 300}, {'name': 'Yelp', 'number_of_employees': 800}, {'name': 'Dailymotion', 'number_of_employees': 120}, {'name': 'RockYou', 'number_of_employees': 106}, {'name': 'Meebo', 'number_of_employees': 200}, {'name': 'Eventbrite', 'number_of_employees': 200}, {'name': 'Box', 'number_of_employees': 950}, {'name': 'Conduit', 'number_of_employees': 215}, {'name': 'Redfin', 'number_of_employees': 100}, {'name': 'oDesk', 'number_of_employees': 120}, {'name': 'Simply Hired', 'number_of_employees': 100}, {'name': 'PhotoBox', 'number_of_employees': 600}, {'name': 'Spreadshirt', 'number_of_employees': 230}, {'name': 
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
ipop=db.companies.find({},{'name':1,'_id':0}).sort('ipo.price',-1).limit(50)
print(list(ipop))
#Limito a 50 debido al siguiente aviso:
#Sort operation used more than the maximum 33554432 bytes of RAM
# Out:
# [{'name': 'AdventNet'}, {'name': 'Wetpaint'}, {'name': 'Zoho'}, {'name': 'Omnidrive'}, {'name': 'Geni'}, {'name': 'Digg'}, {'name': 'Flektor'}, {'name': 'Postini'}, {'name': 'Fox Interactive Media'}, {'name': 'StumbleUpon'}, {'name': 'Gizmoz'}, {'name': 'Scribd'}, {'name': 'Lala'}, {'name': 'Helio'}, {'name': 'Slacker'}, {'name': 'MeetMoi'}, {'name': 'Joost'}, {'name': 'Twitter'}, {'name': 'Viacom'}, {'name': 'Babelgum'}, {'name': 'Facebook'}, {'name': 'CBS'}, {'name': 'Plaxo'}, {'name': 'eBay'}, {'name': 'Powerset'}, {'name': 'SpinVox'}, {'name': 'Technorati'}, {'name': 'AddThis'}, {'name': 'Mahalo'}, {'name': 'OpenX'}, {'name': 'Sparter'}, {'name': 'Veoh'}, {'name': 'Kyte'}, {'name': 'Gannett'}, {'name': 'Thoof'}, {'name': 'Info'}, {'name': 'Jingle Networks'}, {'name': 'Cisco'}, {'name': 'Mercora'}, {'name': 'NetRatings'}, {'name': 'LifeLock'}, {'name': 'Wesabe'}, {'name': 'Jangl SMS'}, {'name': 'SmugMug'}, {'name': 'Prosper'}, {'name': 'JotSpot'}, {'name': 'Meetup'}, {'name': 'Yah
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
emp_ord=db.companies.find({},{'name':1,'_id':0}).sort('number_of_employees',-1).limit(50)
print(list(emp_ord))
# Out:
# [{'name': 'Siemens'}, {'name': 'IBM'}, {'name': 'Toyota'}, {'name': 'PayPal'}, {'name': 'Nippon Telegraph and Telephone Corporation'}, {'name': 'Samsung Electronics'}, {'name': 'Accenture'}, {'name': 'Tata Consultancy Services'}, {'name': 'Flextronics International'}, {'name': 'Safeway'}, {'name': 'Sony'}, {'name': 'LG'}, {'name': 'Ford'}, {'name': 'Boeing'}, {'name': 'Digital Equipment Corporation'}, {'name': 'Nokia'}, {'name': 'MItsubishi Electric'}, {'name': 'MItsubishi Electric'}, {'name': 'Comcast'}, {'name': 'Bertelsmann'}, {'name': 'MetaCarta'}, {'name': 'General Dynamics'}, {'name': 'Microsoft'}, {'name': 'CSC'}, {'name': 'CSC'}, {'name': 'Intel'}, {'name': 'Cox Enterprises'}, {'name': 'Apple'}, {'name': 'Dell'}, {'name': '3M'}, {'name': 'Alcatel-Lucent'}, {'name': 'ExxonMobil'}, {'name': 'Affiliated Computer Services'}, {'name': 'CGI Group'}, {'name': 'Cisco'}, {'name': 'Xerox'}, {'name': 'Motorola Solutions'}, {'name': 'Thomson Reuters'}, {'name': 'Thomson Reuters'}, {'name
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
fm=db.companies.find({'founded_month':{'$gt':5}},{'name':1,'_id':0}).limit(1000)
print(list(fm))
# Out:
# [{'name': 'Wetpaint'}, {'name': 'Zoho'}, {'name': 'Omnidrive'}, {'name': 'Geni'}, {'name': 'Digg'}, {'name': 'Postini'}, {'name': 'Fox Interactive Media'}, {'name': 'Joost'}, {'name': 'Plaxo'}, {'name': 'eBay'}, {'name': 'Powerset'}, {'name': 'Technorati'}, {'name': 'Sparter'}, {'name': 'Kyte'}, {'name': 'Thoof'}, {'name': 'Jingle Networks'}, {'name': 'LifeLock'}, {'name': 'Wesabe'}, {'name': 'SmugMug'}, {'name': 'Skype'}, {'name': 'Pando Networks'}, {'name': 'Ikan'}, {'name': 'delicious'}, {'name': 'Topix'}, {'name': 'Pownce'}, {'name': 'AllPeers'}, {'name': 'Wize'}, {'name': 'AllofMP3'}, {'name': 'SellABand'}, {'name': 'MeeVee'}, {'name': 'blinkx'}, {'name': 'iContact'}, {'name': 'Zlio'}, {'name': 'Jaiku'}, {'name': 'Yelp'}, {'name': 'Yapta'}, {'name': 'Fleck'}, {'name': 'SideStep'}, {'name': 'Google'}, {'name': 'Instructables'}, {'name': 'RockYou'}, {'name': 'Swivel'}, {'name': 'Netvibes'}, {'name': 'Slide'}, {'name': 'TripHub'}, {'name': 'CrowdVine'}, {'name': 'TVtrip'}, {'name':
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
dp=db.companies.find({'founded_year':{'$lt':2000},'acquisition.price_amount':{'$gt':10000000}},{'name':1,'_id':0})
print(list(dp))
# Out:
# [{'name': 'Postini'}, {'name': 'SideStep'}, {'name': 'Recipezaar'}, {'name': 'PayPal'}, {'name': 'Snapfish'}, {'name': 'Neopets'}, {'name': 'Sun Microsystems'}, {'name': 'Zappos'}, {'name': 'Alibaba'}, {'name': 'Sabre'}, {'name': 'Lastminute'}, {'name': 'Sportsline'}, {'name': 'Webshots'}, {'name': 'Digitas'}, {'name': 'MIVA'}, {'name': 'iVillage'}, {'name': 'PriceGrabber'}, {'name': 'LinkShare'}, {'name': 'Kaboose'}, {'name': 'Fastclick'}, {'name': 'Eloqua'}, {'name': 'Interwoven'}, {'name': 'Omniture'}, {'name': 'HowStuffWorks'}, {'name': 'RealAge'}, {'name': 'Match'}, {'name': 'Xdrive'}, {'name': 'Alexa'}, {'name': 'Offermatica'}, {'name': 'ioko'}, {'name': 'MyNewPlace'}, {'name': 'DoubleClick'}, {'name': 'Danger'}, {'name': 'Direct Hit'}, {'name': 'BEA Systems'}, {'name': 'Napster'}, {'name': 'SafeNet'}, {'name': 'LowerMyBills'}, {'name': 'Various'}, {'name': 'aQuantive'}, {'name': 'PeopleSupport'}, {'name': 'Wedding Channel'}, {'name': 'iCrossing'}, {'name': 'Responsys'}, {'name
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
acq=db.companies.find({'acquisition.acquired_year':{'$gt':2015}},{'name':1,'acquisition.price_amount':1,'_id':0}).sort('acquisition.price_amount',1)
print(list(acq))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
fy=db.companies.find({},{'name':1,'founded_year':1,'_id':0}).sort('founded_year',1).limit(1000)
print(list(fy))
#Limited because of the same execution error reported elsewhere
# Out:
# [{'name': 'Flektor', 'founded_year': None}, {'name': 'Lala', 'founded_year': None}, {'name': 'SpinVox', 'founded_year': None}, {'name': 'Gannett', 'founded_year': None}, {'name': 'Info', 'founded_year': None}, {'name': 'Mercora', 'founded_year': None}, {'name': 'NetRatings', 'founded_year': None}, {'name': 'JotSpot', 'founded_year': None}, {'name': 'There', 'founded_year': None}, {'name': 'Tun3r', 'founded_year': None}, {'name': 'PlaceBlogger', 'founded_year': None}, {'name': 'Cuts', 'founded_year': None}, {'name': 'Edgeio', 'founded_year': None}, {'name': 'revlayer', 'founded_year': None}, {'name': 'Parakey', 'founded_year': None}, {'name': 'PowerReviews', 'founded_year': None}, {'name': 'WikiYou', 'founded_year': None}, {'name': 'Going', 'founded_year': None}, {'name': 'DZOIC', 'founded_year': None}, {'name': 'ProfileBuilder', 'founded_year': None}, {'name': 'Truemors', 'founded_year': None}, {'name': 'CollegeWikis', 'founded_year': None}, {'name': 'Hotswap', 'founded_year': None},
# ...

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
fa=db.companies.find({'founded_day':{'$lt':8}},{'name':1,'_id':0}).sort('acquisition.price_amount',-1).limit(10)
print(list(fa))
# Out:
# [{'name': 'Netscape'}, {'name': 'PayPal'}, {'name': 'Zappos'}, {'name': 'Alibaba'}, {'name': 'Postini'}, {'name': 'Danger'}, {'name': 'Clearwell Systems'}, {'name': 'PrimeSense'}, {'name': 'Amobee'}, {'name': 'BlueLithium'}]

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
cat=db.companies.find({'category_code':'web','number_of_employees':{'$gt':4000}},{'name':1,'_id':0}).sort('number_of_employees',1)
print(list(cat))
# Out:
# [{'name': 'Expedia'}, {'name': 'AOL'}, {'name': 'Webkinz'}, {'name': 'Rakuten'}, {'name': 'Los Angeles Times Media Group'}, {'name': 'Groupon'}, {'name': 'Yahoo!'}, {'name': 'eBay'}, {'name': 'Experian'}]

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
aca=db.companies.find({'acquisition.price_amount':{'$gt':10000000},'price_currency_code':'EUR'})
print(list(aca))
# Out:
# []

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
fty=db.companies.find({'founded_month':{'$lt':7}},{'name':1,'acquisition':1,'_id':0}).limit(10)
print(list(fty))
# Out:
# [{'name': 'Geni', 'acquisition': {'price_amount': None, 'price_currency_code': 'USD', 'term_code': None, 'source_url': 'http://techcrunch.com/2012/11/28/all-in-the-family-myheritage-buys-former-yammer-stablemate-geni-com-raises-25m/', 'source_description': 'MyHeritage acquires Geni and $25M to build family tree of the whole world', 'acquired_year': 2012, 'acquired_month': 11, 'acquired_day': 28, 'acquiring_company': {'name': 'MyHeritage', 'permalink': 'myheritage'}}}, {'name': 'Postini', 'acquisition': {'price_amount': 625000000, 'price_currency_code': 'USD', 'term_code': 'cash', 'source_url': 'http://www.techcrunch.com/2007/07/09/google-acquires-postini-for-625-million/', 'source_description': 'http://www.techcrunch.com/2007/07/09/google-acquires-postini-for-625-million/', 'acquired_year': 2007, 'acquired_month': 7, 'acquired_day': 9, 'acquiring_company': {'name': 'Google', 'permalink': 'google'}}}, {'name': 'Fox Interactive Media', 'acquisition': None}, {'name': 'StumbleUpon', 'acq
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
facq=db.companies.find({'founded_year':{'$gt':1999, '$lt':2011}, 'acquisition.acquired_year':{'$gt':2010}},{'name':1,'_id':0})
print(list(facq))
# Out:
# [{'name': 'Wetpaint'}, {'name': 'Geni'}, {'name': 'Digg'}, {'name': 'Kyte'}, {'name': 'Jingle Networks'}, {'name': 'blogTV'}, {'name': 'delicious'}, {'name': 'Revision3'}, {'name': 'iContact'}, {'name': 'Mashery'}, {'name': 'KickApps'}, {'name': 'Dailymotion'}, {'name': 'Instructables'}, {'name': 'Netvibes'}, {'name': 'Dogster'}, {'name': 'adBrite'}, {'name': 'Meebo'}, {'name': 'Seesmic'}, {'name': 'Zvents'}, {'name': 'Oodle'}, {'name': 'Flixster'}, {'name': 'IceRocket'}, {'name': 'hi5'}, {'name': 'Indeed'}, {'name': 'Grockit'}, {'name': 'Zenfolio'}, {'name': 'Wishpot'}, {'name': 'Retrevo'}, {'name': 'SelectMinds'}, {'name': 'Flock'}, {'name': 'TokBox'}, {'name': 'Six Apart'}, {'name': 'TimeBridge'}, {'name': 'Doostang'}, {'name': 'MySpace'}, {'name': 'Docstoc'}, {'name': 'Vlingo'}, {'name': 'sezmi'}, {'name': 'Greystripe'}, {'name': 'LocaModa'}, {'name': 'Thumbplay'}, {'name': 'OMGPOP'}, {'name': 'Daylife'}, {'name': 'Behance'}, {'name': 'Attributor'}, {'name': 'WooMe'}, {'name': 'V
# ...
