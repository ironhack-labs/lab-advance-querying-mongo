# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
a = db.companies.find( { 'name': 'Babelgum' },
                      { 'name': 1, '_id': 0 } )

for e in a:
    print (e['name'])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
b = db.companies.find({'number_of_employees': {'$gt':5000}}).limit(20).sort('number_of_employees')
for e in b:
    print(e['name'], e['number_of_employees'])
# Out:
# Nintendo 5080
# Hexaware Technologies 5200
# Facebook 5299
# OpenText 5300
# LSI 5400
# CPM Braxis 5400
# Microchip Technologies 5500
# Mediaset 5729
# Mindray Medical International 5763
# Baidu 6000
# Dentsu 6000
# Tata Communications 6000
# Atmel 6000
# Acxiom 6200
# Acxiom 6200
# SRA International 6400
# Moody's 6800
# ManTech 7000
# Adobe Systems 7173
# Broadcom 7400

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
c = db.companies.find({'$and': [{'founded_year': {'$gte':2000} },
                                {'founded_year': {'$lte':2005}}]}).limit(100)
for e in c:
    print(e['name'], e['founded_year'])
# Out:
# Zoho 2005
# Wetpaint 2005
# Digg 2004
# Omnidrive 2005
# Gizmoz 2003
# StumbleUpon 2002
# Helio 2005
# Plaxo 2002
# Facebook 2004
# Technorati 2002
# AddThis 2004
# Veoh 2004
# Jingle Networks 2005
# Meetup 2002
# Jangl SMS 2005
# LifeLock 2005
# Wesabe 2005
# SmugMug 2002
# Jajah 2005
# Pando Networks 2004
# YouTube 2005
# Skype 2003
# Jobster 2004
# AllPeers 2004
# Revision3 2005
# Topix 2002
# iSkoot 2005
# Ikan 2003
# delicious 2003
# AllofMP3 2000
# Steorn 2000
# MeeVee 2000
# iContact 2003
# ClipBlast! 2005
# Zlio 2005
# Yelp 2004
# Coghead 2003
# blinkx 2004
# Farecast 2003
# Dailymotion 2005
# KickApps 2004
# RockYou 2005
# Instructables 2005
# Swivel 2005
# Netvibes 2005
# Flickr 2004
# Slide 2005
# Bebo 2005
# TripHub 2005
# FeedBurner 2004
# Dogster 2004
# Sway 2004
# CornerWorld 2002
# PBworks 2005
# adBrite 2003
# Loomia 2004
# Newsvine 2005
# Jamendo 2005
# Meebo 2005
# iLike 2002
# Conduit 2005
# LinkedIn 2003
# Kaboodle 2005
# Wink 2004
# Redfin 2004
# Box 2005
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
d = db.companies.find({'$and': [{'ipo.valuation_amount': {'$gt':100000000}},
                                {'founded_year': {'$lt':2010}}]})
for e in d:
    print(e['name'], e['ipo'])
# Out:
# Twitter {'valuation_amount': 18100000000, 'valuation_currency_code': 'USD', 'pub_year': 2013, 'pub_month': 11, 'pub_day': 7, 'stock_symbol': 'NYSE:TWTR'}
# Facebook {'valuation_amount': 104000000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 5, 'pub_day': 18, 'stock_symbol': 'NASDAQ:FB'}
# Yelp {'valuation_amount': 1300000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 3, 'pub_day': 2, 'stock_symbol': 'NYSE:YELP'}
# LinkedIn {'valuation_amount': 9310000000, 'valuation_currency_code': 'USD', 'pub_year': 2011, 'pub_month': 7, 'pub_day': 20, 'stock_symbol': 'NYSE:LNKD'}
# Brightcove {'valuation_amount': 290000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 2, 'pub_day': 17, 'stock_symbol': 'NASDAQ:BCOV'}
# Amazon {'valuation_amount': 100000000000, 'valuation_currency_code': 'USD', 'pub_year': 1997, 'pub_month': 5, 'pub_day': None, 'stock_symbol': 'NASDAQ:AMZN'}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
e = db.companies.find({'$and':[{'number_of_employees': {'$lt':1000}},
                               {'founded_year': {'$lt':2005}}]}).limit(10).sort('number_of_employees',-1)

for p in e:
    print(p['name'], p['number_of_employees'])
# Out:
# Infinera Corporation 974
# NorthPoint Communications Group 948
# 888 Holdings 931
# Forrester Research 903
# SonicWALL 900
# Webmetrics 900
# Cornerstone OnDemand 881
# Yelp 800
# ZoomInfo 800
# MySpace 800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
f = db.companies.find({'partners': {'$exists': False}})
    
if list(f) == []:
    print ('All companies have partners field')

for e in f:
    print (e['name'])
# Out:
# All companies have partners field

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
g = db.companies.find({'category_code': {'$type': 'null'}}).limit(50)
for e in g:
    print(e['name'])
# Out:
# Collective
# Snimmer
# KoolIM
# Level9 Media
# VidKing
# Drigg
# SpaceTime
# MMDAYS
# Touch Clarity
# Inside Group
# Repeater Store
# Tapesh
# iPersians
# NewPersia
# Pyra Labs
# Feedmap
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Picturehouse
# Covalent Technologies
# Epic Trip
# Telepost
# Fidelity
# Quirk
# Leechblock
# Skyrove
# My Success Gateway
# The Easynet Group
# RealNames
# NetNames
# Sniperoo
# JD Project
# ABC News
# Teoma Technologies
# cometro
# U-Cast
# TechJuicer
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Invitastic
# Windows Live Events
# News Futures
# Foresight Exchange

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
h = db.companies.find({'$and': [{'number_of_employees': {'$gte': 100}},
                                {'number_of_employees': {'$lt': 1000}}]}).limit(50)
for e in h:
    print(e['name'], e['number_of_employees'])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Conduit 215
# Redfin 100
# Box 950
# oDesk 120
# Simply Hired 100
# PhotoBox 600
# Spreadshirt 230
# spigit 120
# Bazaarvoice 600
# PowerReviews 120
# hi5 100
# Tagged 162
# PayScale 130
# Truphone 450
# Hightail 200
# Nimbuzz 140
# Brightcove 220
# IMVU 150
# INgage Networks 100
# MobiTV 300
# Dropbox 350
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# ZoomInfo 800
# Zango 225
# MySpace 800
# Trulia 500
# TechTarget 600
# TubeMogul 230
# Sportsline 264
# Espotting 250
# OpenTable 550
# airG 180
# Adknowledge 300
# ChannelAdvisor 300
# Ooyala 300

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
i = db.companies.find().sort('ipo.valuation_amount', -1).limit(50)
for e in i:
    print(e['name'])
# Out:
# GREE
# Facebook
# Amazon
# Twitter
# Groupon
# Tencent
# Western Digital
# LinkedIn
# BMC Software
# Rackspace
# Baidu
# TripAdvisor
# HomeAway
# Zillow
# Nielsen
# Yelp
# Chegg
# Chegg
# RPX Corporation
# Higher One
# OpenTable
# Jive Software
# BrightSource Energy
# QlikTech
# Millennial Media
# Mixi
# Cornerstone OnDemand
# Infoblox
# SolarWinds
# Wix
# Marketo
# Opsware
# Emdeon
# Shutterfly
# Telenav
# Rally Software
# STR
# Brightcove
# ChannelAdvisor
# Elster Group
# DemandTec
# KIT digital
# Tudou
# DivX
# QuinStreet
# Geeknet
# Salesforce
# JumpTV
# EnerNOC
# Meru Networks

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
j = db.companies.find().sort('number_of_employees', -1).limit(50)
for e in j:
    print(e['name'], e['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000
# Sony 180500
# LG 177000
# Ford 171000
# Boeing 160000
# Digital Equipment Corporation 140000
# Nokia 125000
# MItsubishi Electric 107000
# MItsubishi Electric 107000
# Comcast 100000
# Bertelsmann 100000
# MetaCarta 99999
# General Dynamics 92900
# Microsoft 90000
# CSC 90000
# CSC 90000
# Intel 86300
# Cox Enterprises 83000
# Apple 80000
# Dell 80000
# 3M 79183
# Alcatel-Lucent 77000
# ExxonMobil 76900
# Affiliated Computer Services 74000
# CGI Group 72000
# Cisco 63000
# Xerox 57400
# Motorola Solutions 51000
# Thomson Reuters 50000
# Thomson Reuters 50000
# Telstra 39000
# Bristol-Myers Squibb 35000
# Nike 34300
# Sun Microsystems 33350
# Nortel Networks 30307
# Texas Instruments 30175
# Google 28000
# LabCorp 28000
# TELUS 26000
# ...

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
k = db.companies.find({'founded_month': {'$gt': 6}}).limit(1000)
for e in k:
    print(e['name'], e['founded_month'])
# Out:
# Zoho 9
# Wetpaint 10
# Digg 10
# Omnidrive 11
# Joost 10
# Plaxo 11
# eBay 9
# Powerset 10
# Thoof 12
# Jingle Networks 9
# LifeLock 8
# Kyte 12
# Wesabe 12
# SmugMug 11
# Pando Networks 7
# Skype 8
# AllPeers 8
# Wize 8
# Ikan 12
# delicious 9
# SellABand 8
# MeeVee 7
# iContact 7
# Zlio 11
# Jaiku 7
# Yelp 7
# Yapta 7
# Fleck 11
# blinkx 12
# SideStep 11
# RockYou 11
# Instructables 8
# Swivel 12
# Netvibes 9
# Slide 8
# CrowdVine 8
# TheFind 10
# Google 9
# Sway 12
# CornerWorld 9
# FlickIM 12
# Terabitz 7
# Kaboodle 10
# Wink 8
# GigaOM 7
# Redfin 10
# Go2Web20 9
# TechnologyGuide 10
# Techmeme 10
# Ujogo 7
# Recipezaar 9
# Gumiyo 11
# stylediary 8
# Piczo 11
# Cyworld 7
# Socialtext 12
# ConnectMeAnywhere 9
# Clipperz 11
# Nintendo 9
# hi5 12
# Cerado 7
# Tagged 10
# Indeed 11
# ONEsite 9
# Wallhogs 8
# Jaxtr 10
# eBuddy 9
# Grockit 12
# JumpBox 7
# Relationals 7
# LongJump 7
# Phonezoo 11
# Wishpot 11
# Forbes 8
# Rebtel 7
# Boonex 7
# IntenseDebate 12
# Adobe Systems 12
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.
