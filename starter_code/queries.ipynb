# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
data={'name':'Babelgum'}
print(data['name'])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
cur = db.companies.find ({ 'number_of_employees': { '$gt': 5000 } }).limit(20).sort('number_of_employees')
for x in cur:
    print(x['name'], x['number_of_employees'])
# Out:
# Nintendo 5080
# Hexaware Technologies 5200
# Facebook 5299
# OpenText 5300
# LSI 5400
# CPM Braxis 5400
# Microchip Technologies 5500
# Mediaset 5729
# Mindray Medical International 5763
# Baidu 6000
# Dentsu 6000
# Tata Communications 6000
# Atmel 6000
# Acxiom 6200
# Acxiom 6200
# SRA International 6400
# Moody's 6800
# ManTech 7000
# Adobe Systems 7173
# Broadcom 7400

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
cur1 = db.companies.find( { '$and': [ { 'founded_year': { '$gt': 2000 } }, { 'founded_year': { '$lt': 2005 } }] } )
#db.inventory.find( { $or: [ { quantity: { $lt: 20 } }, { price: 10 } ] } )
for y in cur1:
    print(y['name'], y['founded_year'])
# Out:
# TechnologyGuide 2001
# Digg 2004
# Facebook 2004
# Gizmoz 2003
# StumbleUpon 2002
# Plaxo 2002
# Technorati 2002
# AddThis 2004
# Veoh 2004
# Meetup 2002
# SmugMug 2002
# Skype 2003
# Pando Networks 2004
# Ikan 2003
# delicious 2003
# Topix 2002
# Jobster 2004
# AllPeers 2004
# iContact 2003
# blinkx 2004
# Yelp 2004
# Coghead 2003
# Farecast 2003
# KickApps 2004
# Flickr 2004
# FeedBurner 2004
# Dogster 2004
# Sway 2004
# CornerWorld 2002
# adBrite 2003
# Loomia 2004
# LinkedIn 2003
# iLike 2002
# Redfin 2004
# Wink 2004
# Techmeme 2004
# Eventful 2004
# Oodle 2004
# Simply Hired 2004
# ooma 2004
# stylediary 2004
# Vast 2001
# MyPublicInfo 2004
# Spreadshirt 2002
# Socialtext 2002
# IceRocket 2004
# Ohloh 2004
# hi5 2003
# Tagged 2004
# Indeed 2004
# Cerado 2002
# introNetworks 2003
# eBuddy 2003
# PeerMe 2004
# Crackle 2004
# Clipmarks 2003
# Brightcove 2004
# Hightail 2004
# TalkPlus 2004
# Vudu 2004
# Kaneva 2004
# IMVU 2004
# Userplane 2001
# Dubit 2003
# Millsberry 2004
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
cur2 = db.companies.find( { '$and': [ { 'ipo.valuation_amount': { '$gt': 100000000 } }, { 'founded_year': { '$lt': 2010 } }] } )
#db.inventory.find( { $or: [ { quantity: { $lt: 20 } }, { price: 10 } ] } )
for a in cur2:
    print(a['name'], a['ipo'])
# Out:
# Facebook {'pub_day': 18, 'valuation_currency_code': 'USD', 'valuation_amount': 104000000000, 'pub_year': 2012, 'stock_symbol': 'NASDAQ:FB', 'pub_month': 5}
# Twitter {'pub_day': 7, 'valuation_currency_code': 'USD', 'valuation_amount': 18100000000, 'pub_year': 2013, 'stock_symbol': 'NYSE:TWTR', 'pub_month': 11}
# Yelp {'pub_day': 2, 'valuation_currency_code': 'USD', 'valuation_amount': 1300000000, 'pub_year': 2012, 'stock_symbol': 'NYSE:YELP', 'pub_month': 3}
# LinkedIn {'pub_day': 20, 'valuation_currency_code': 'USD', 'valuation_amount': 9310000000, 'pub_year': 2011, 'stock_symbol': 'NYSE:LNKD', 'pub_month': 7}
# Amazon {'pub_day': None, 'valuation_currency_code': 'USD', 'valuation_amount': 100000000000, 'pub_year': 1997, 'stock_symbol': 'NASDAQ:AMZN', 'pub_month': 5}
# Brightcove {'pub_day': 17, 'valuation_currency_code': 'USD', 'valuation_amount': 290000000, 'pub_year': 2012, 'stock_symbol': 'NASDAQ:BCOV', 'pub_month': 2}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
cur3 = db.companies.find( { '$and': [ { 'number_of_employees': { '$lt': 1000 } }, { 'founded_year': { '$lt': 2005 } }] } ).limit(10).sort('number_of_employees',-1)
#db.inventory.find( { $or: [ { quantity: { $lt: 20 } }, { price: 10 } ] } )
for b in cur3:
    print(b['name'], b['number_of_employees'])
# Out:
# Infinera Corporation 974
# NorthPoint Communications Group 948
# 888 Holdings 931
# Forrester Research 903
# SonicWALL 900
# Webmetrics 900
# Cornerstone OnDemand 881
# Yelp 800
# MySpace 800
# ZoomInfo 800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
cur4 = db.companies.find( { 'partners': { '$exists': False } })
for c in cur4:
    print(c['name'])

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
cur5 = db.companies.find( { 'category_code': None } )
for d in cur5:
    print(d['name'])
# Out:
# Snimmer
# Drigg
# MMDAYS
# Collective
# KoolIM
# Level9 Media
# VidKing
# SpaceTime
# Touch Clarity
# Inside Group
# Repeater Store
# Tapesh
# iPersians
# NewPersia
# Pyra Labs
# Feedmap
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Picturehouse
# Covalent Technologies
# Epic Trip
# Telepost
# Fidelity
# Quirk
# Skyrove
# Leechblock
# My Success Gateway
# RealNames
# The Easynet Group
# NetNames
# Sniperoo
# JD Project
# ABC News
# Teoma Technologies
# cometro
# U-Cast
# TechJuicer
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Invitastic
# Windows Live Events
# News Futures
# Foresight Exchange
# Greenspun
# American Solutions
# Media Run
# Tonic Studios
# USLegalForms
# Livevault
# Vector Capital
# Neudesic
# TuneCircle
# Hotbar
# eWeb Productions
# FatPort
# Excilan SA
# SEO Toolset
# ClarityBlue
# Reuters
# Guru
# Paxfire
# Digital-Telepathy
# Pidgin Technologies
# Time Lending California
# Gazprom-Media
# reQall
# Fon11
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
cur6 = db.companies.find( { '$and': [ { 'number_of_employees': { '$gt': 100 } }, { 'number_of_employees': { '$lt': 1000 } }] } )
for f in cur6:
    print(f['name'], f['number_of_employees'])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Eventbrite 200
# Box 950
# Conduit 215
# oDesk 120
# PhotoBox 600
# Spreadshirt 230
# Bazaarvoice 600
# spigit 120
# PowerReviews 120
# Tagged 162
# PayScale 130
# Truphone 450
# Brightcove 220
# Hightail 200
# Nimbuzz 140
# IMVU 150
# Dropbox 350
# MobiTV 300
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# MySpace 800
# ZoomInfo 800
# Zango 225
# Trulia 500
# TubeMogul 230
# TechTarget 600
# Sportsline 264
# OpenTable 550
# Espotting 250
# Adknowledge 300
# airG 180
# ChannelAdvisor 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# Mozilla 800
# Kaltura 160
# Zillow 600
# Moz 130
# Zimbra 200
# Wamba 120
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# uTest 120
# Payoneer 200
# Shopatron 166
# Wix 400
# tyntec 150
# Gigya 230
# Alipay 500
# MyBuys 120
# Zecco 110
# uShip 190
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
cur7 = db.companies.find().sort('ipo.valuation_amount', -1).limit(20)
for g in cur7:
    print(g['name'])
# Out:
# GREE
# Facebook
# Amazon
# Twitter
# Groupon
# Tencent
# Western Digital
# LinkedIn
# BMC Software
# Rackspace
# Baidu
# TripAdvisor
# HomeAway
# Zillow
# Nielsen
# Yelp
# Chegg
# Chegg
# RPX Corporation
# Higher One

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
cur8 = db.companies.find().sort('number_of_employees', -1).limit(10)
for h in cur8:
    print(h['name'], h['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.
