# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
result = db.companies.find({'name': 'Babelgum'}, {
    "name": 1,
    "_id": 0
})

display(list(result))
# Out:
# [{'name': 'Babelgum'}]

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
result = db.companies.find({'number_of_employees': {'$gt': 5000}}, {
    "name": 1,
    "number_of_employees": 1,
    "_id": 0
}).sort([("number_of_employees", -1)]).limit(20)

display(list(result))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000},
#  {'name': 'Sony', 'number_of_employees': 180500},
#  {'name': 'LG', 'number_of_employees': 177000},
#  {'name': 'Ford', 'number_of_employees': 171000},
#  {'name': 'Boeing', 'number_of_employees': 160000},
#  {'name': 'Digital Equipment Corporation', 'number_of_employees': 140000},
#  {'name': 'Nokia', 'number_of_employees': 125000},
# ...

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
result = db.companies.find({'$and': [{'founded_year': {'$gte': 2000}}, {'founded_year': {'$lte': 2005}}]}, {
    "name": 1,
    "founded_year": 1,
    "_id": 0
}).sort([('founded_year', 1)])

display(list(result))
# Out:
# [{'name': 'AllofMP3', 'founded_year': 2000},
#  {'name': 'Steorn', 'founded_year': 2000},
#  {'name': 'MeeVee', 'founded_year': 2000},
#  {'name': 'PhotoBox', 'founded_year': 2000},
#  {'name': 'Boonex', 'founded_year': 2000},
#  {'name': 'Sulake', 'founded_year': 2000},
#  {'name': 'SelectMinds', 'founded_year': 2000},
#  {'name': 'ContextWeb', 'founded_year': 2000},
#  {'name': 'ZoomInfo', 'founded_year': 2000},
#  {'name': 'eHarmony', 'founded_year': 2000},
#  {'name': 'Espotting', 'founded_year': 2000},
#  {'name': 'airG', 'founded_year': 2000},
#  {'name': 'Marchex', 'founded_year': 2000},
#  {'name': 'ContactOffice', 'founded_year': 2000},
#  {'name': 'WooMe', 'founded_year': 2000},
#  {'name': 'Boomi', 'founded_year': 2000},
#  {'name': 'zSlide', 'founded_year': 2000},
#  {'name': 'Phrasebase', 'founded_year': 2000},
#  {'name': 'Ubertor', 'founded_year': 2000},
#  {'name': 'JobDig', 'founded_year': 2000},
#  {'name': 'Quigo', 'founded_year': 2000},
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
result = db.companies.find({
    'ipo.valuation_amount': {'$gte': 100000000},
    'founded_year': {'$lt': 2010}
}, {
    "name": 1,
    "ipo.valuation_amount": 1,
    "_id": 0
})

display(list(result))
# Out:
# [{'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000}},
#  {'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000}},
#  {'name': 'Yelp', 'ipo': {'valuation_amount': 1300000000}},
#  {'name': 'LinkedIn', 'ipo': {'valuation_amount': 9310000000}},
#  {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000}},
#  {'name': 'Brightcove', 'ipo': {'valuation_amount': 290000000}},
#  {'name': 'KIT digital', 'ipo': {'valuation_amount': 235000000}},
#  {'name': 'Nielsen', 'ipo': {'valuation_amount': 1600000000}},
#  {'name': 'OpenTable', 'ipo': {'valuation_amount': 1050000000}},
#  {'name': 'ChannelAdvisor', 'ipo': {'valuation_amount': 287000000}},
#  {'name': 'Jive Software', 'ipo': {'valuation_amount': 1000000000}},
#  {'name': 'Zillow', 'ipo': {'valuation_amount': 2550000000}},
#  {'name': 'Wix', 'ipo': {'valuation_amount': 750000000}},
#  {'name': 'Shutterfly', 'ipo': {'valuation_amount': 350000000}},
#  {'name': 'TripAdvisor', 'ipo': {'valuation_amount': 3273770000}},
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
result = db.companies.find({
    'number_of_employees': {'$lt': 1000},
    'founded_year': {'$lt': 2005}
}, {
    "name": 1,
    "number_of_employees": 1,
    "founded_year": 1,
    "_id": 0
}).sort([("number_of_employees", 1)]).limit(10)

display(list(result))
# Out:
# [{'name': 'Fox Interactive Media',
#   'number_of_employees': 0,
#   'founded_year': 1979},
#  {'name': 'Skype', 'number_of_employees': 0, 'founded_year': 2003},
#  {'name': 'Ticketmaster', 'number_of_employees': 0, 'founded_year': 1976},
#  {'name': 'stylediary', 'number_of_employees': 0, 'founded_year': 2004},
#  {'name': 'MindTouch', 'number_of_employees': 0, 'founded_year': 2004},
#  {'name': 'Simpy', 'number_of_employees': 0, 'founded_year': 2004},
#  {'name': 'Eurekster', 'number_of_employees': 0, 'founded_year': 2004},
#  {'name': 'Compete', 'number_of_employees': 0, 'founded_year': 2000},
#  {'name': 'EditGrid', 'number_of_employees': 0, 'founded_year': 2003},
#  {'name': 'Monster', 'number_of_employees': 0, 'founded_year': 1994}]

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
result = db.companies.find({'partners': {"$exists" : False}})
display(list(result))
# Out:
# []

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
result = db.companies.find({'category_code': {'$eq': None}}, 
{
    "name": 1,
    "category_code": 1,
    "_id": 0
})
display(list(result))
# Out:
# [{'name': 'Collective', 'category_code': None},
#  {'name': 'Snimmer', 'category_code': None},
#  {'name': 'KoolIM', 'category_code': None},
#  {'name': 'Level9 Media', 'category_code': None},
#  {'name': 'VidKing', 'category_code': None},
#  {'name': 'Drigg', 'category_code': None},
#  {'name': 'SpaceTime', 'category_code': None},
#  {'name': 'Touch Clarity', 'category_code': None},
#  {'name': 'MMDAYS', 'category_code': None},
#  {'name': 'Inside Group', 'category_code': None},
#  {'name': 'Repeater Store', 'category_code': None},
#  {'name': 'Tapesh', 'category_code': None},
#  {'name': 'iPersians', 'category_code': None},
#  {'name': 'NewPersia', 'category_code': None},
#  {'name': 'Pyra Labs', 'category_code': None},
#  {'name': 'Feedmap', 'category_code': None},
#  {'name': 'NuvoMedia', 'category_code': None},
#  {'name': 'Intwine', 'category_code': None},
#  {'name': 'The Weinstein Company', 'category_code': None},
#  {'name': 'ExecuNet', 'category_code': None},
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
result = db.companies.find({'$and': [{'number_of_employees': {'$gte': 100}}, {'number_of_employees': {'$lt': 1000}}]}, {
    "name": 1,
    "number_of_employees": 1,
    "_id": 0
})

display(list(result))
# Out:
# [{'name': 'AdventNet', 'number_of_employees': 600},
#  {'name': 'AddThis', 'number_of_employees': 120},
#  {'name': 'OpenX', 'number_of_employees': 305},
#  {'name': 'LifeLock', 'number_of_employees': 644},
#  {'name': 'Jajah', 'number_of_employees': 110},
#  {'name': 'Livestream', 'number_of_employees': 120},
#  {'name': 'Ustream', 'number_of_employees': 250},
#  {'name': 'iContact', 'number_of_employees': 300},
#  {'name': 'Yelp', 'number_of_employees': 800},
#  {'name': 'Dailymotion', 'number_of_employees': 120},
#  {'name': 'RockYou', 'number_of_employees': 106},
#  {'name': 'Meebo', 'number_of_employees': 200},
#  {'name': 'Eventbrite', 'number_of_employees': 200},
#  {'name': 'Box', 'number_of_employees': 950},
#  {'name': 'Conduit', 'number_of_employees': 215},
#  {'name': 'Redfin', 'number_of_employees': 100},
#  {'name': 'oDesk', 'number_of_employees': 120},
#  {'name': 'Simply Hired', 'number_of_employees': 100},
#  {'name': 'PhotoBox', 'number_of_employees': 600},
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
result = db.companies.find({}, {
    "name": 1,
    "ipo.valuation_amount": 1,
    "_id": 0
}).sort([("ipo.valuation_amount", -1)]).limit(50)

display(list(result))
# Out:
# [{'name': 'GREE', 'ipo': {'valuation_amount': 108960000000}},
#  {'name': 'Facebook', 'ipo': {'valuation_amount': 104000000000}},
#  {'name': 'Amazon', 'ipo': {'valuation_amount': 100000000000}},
#  {'name': 'Twitter', 'ipo': {'valuation_amount': 18100000000}},
#  {'name': 'Groupon', 'ipo': {'valuation_amount': 12800000000}},
#  {'name': 'Tencent', 'ipo': {'valuation_amount': 11000000000}},
#  {'name': 'Western Digital', 'ipo': {'valuation_amount': 9430000000}},
#  {'name': 'LinkedIn', 'ipo': {'valuation_amount': 9310000000}},
#  {'name': 'BMC Software', 'ipo': {'valuation_amount': 6000000000}},
#  {'name': 'Rackspace', 'ipo': {'valuation_amount': 5440000000}},
#  {'name': 'Baidu', 'ipo': {'valuation_amount': 4000000000}},
#  {'name': 'TripAdvisor', 'ipo': {'valuation_amount': 3273770000}},
#  {'name': 'HomeAway', 'ipo': {'valuation_amount': 3000000000}},
#  {'name': 'Zillow', 'ipo': {'valuation_amount': 2550000000}},
#  {'name': 'Nielsen', 'ipo': {'valuation_amount': 1600000000}},
# ...

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
result = db.companies.find({}, {
    "name": 1,
    "number_of_employees": 1,
    "_id": 0
}).sort([("number_of_employees", -1)]).limit(10)

display(list(result))
# Out:
# [{'name': 'Siemens', 'number_of_employees': 405000},
#  {'name': 'IBM', 'number_of_employees': 388000},
#  {'name': 'Toyota', 'number_of_employees': 320000},
#  {'name': 'PayPal', 'number_of_employees': 300000},
#  {'name': 'Nippon Telegraph and Telephone Corporation',
#   'number_of_employees': 227000},
#  {'name': 'Samsung Electronics', 'number_of_employees': 221726},
#  {'name': 'Accenture', 'number_of_employees': 205000},
#  {'name': 'Tata Consultancy Services', 'number_of_employees': 200300},
#  {'name': 'Flextronics International', 'number_of_employees': 200000},
#  {'name': 'Safeway', 'number_of_employees': 186000}]

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
result = db.companies.find({'founded_month': {'$gt': 6}}, {
    "name": 1,
    "founded_month": 1,
    "_id": 0
}).limit(1000)

display(list(result))
# Out:
# [{'name': 'Wetpaint', 'founded_month': 10},
#  {'name': 'Zoho', 'founded_month': 9},
#  {'name': 'Digg', 'founded_month': 10},
#  {'name': 'Omnidrive', 'founded_month': 11},
#  {'name': 'eBay', 'founded_month': 9},
#  {'name': 'Joost', 'founded_month': 10},
#  {'name': 'Plaxo', 'founded_month': 11},
#  {'name': 'Powerset', 'founded_month': 10},
#  {'name': 'Kyte', 'founded_month': 12},
#  {'name': 'Thoof', 'founded_month': 12},
#  {'name': 'Jingle Networks', 'founded_month': 9},
#  {'name': 'LifeLock', 'founded_month': 8},
#  {'name': 'Wesabe', 'founded_month': 12},
#  {'name': 'SmugMug', 'founded_month': 11},
#  {'name': 'Google', 'founded_month': 9},
#  {'name': 'Skype', 'founded_month': 8},
#  {'name': 'Pando Networks', 'founded_month': 7},
#  {'name': 'Ikan', 'founded_month': 12},
#  {'name': 'delicious', 'founded_month': 9},
#  {'name': 'AllPeers', 'founded_month': 8},
#  {'name': 'Wize', 'founded_month': 8},
#  {'name': 'SellABand', 'founded_month': 8},
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %%
result = db.companies.find({'$or': 
    [
    {'deadpooled_year': {'$gt': 3}}, 
    {"$where": "this.deadpooled_year - this.founded_year  > 3"}
    ]
}, {
    "name": 1,
    "founded_year": 1,
    "deadpooled_year": 1,
    "_id": 0
}).sort([('deadpooled_year', 1)])             


display(list(result))
# Out:
# [{'name': 'Weblogs', 'founded_year': 2003, 'deadpooled_year': 1963},
#  {'name': 'Bookrags', 'founded_year': 1999, 'deadpooled_year': 1991},
#  {'name': 'adBrite', 'founded_year': 2003, 'deadpooled_year': 2001},
#  {'name': 'Excite@Home', 'founded_year': 1995, 'deadpooled_year': 2001},
#  {'name': 'Ardesic', 'founded_year': None, 'deadpooled_year': 2001},
#  {'name': 'sportgate AG', 'founded_year': None, 'deadpooled_year': 2001},
#  {'name': 'Webvan', 'founded_year': None, 'deadpooled_year': 2001},
#  {'name': 'RealNames', 'founded_year': 1996, 'deadpooled_year': 2002},
#  {'name': 'SpongeFish', 'founded_year': None, 'deadpooled_year': 2003},
#  {'name': 'MediaRush', 'founded_year': 2000, 'deadpooled_year': 2004},
#  {'name': 'Zooomr', 'founded_year': 2006, 'deadpooled_year': 2006},
#  {'name': 'Zoji', 'founded_year': 2004, 'deadpooled_year': 2006},
#  {'name': 'TrueSpan', 'founded_year': None, 'deadpooled_year': 2006},
# ...

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
result = db.companies.find({'founded_year': {'$lt': 2000}, 'acquisition.price_amount': {'$gt': 10000000}}, {
    "name": 1,
    "acquisition.price_amount": 1,
    "founded_year": 1,
    "_id": 0
})

display(list(result))
# Out:
# [{'name': 'Postini',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 625000000}},
#  {'name': 'SideStep',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 180000000}},
#  {'name': 'Recipezaar',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 25000000}},
#  {'name': 'PayPal',
#   'founded_year': 1998,
#   'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Snapfish',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 300000000}},
#  {'name': 'Neopets',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 160000000}},
#  {'name': 'Sun Microsystems',
#   'founded_year': 1982,
#   'acquisition': {'price_amount': 7400000000}},
#  {'name': 'Zappos',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 1200000000}},
#  {'name': 'Alibaba',
#   'founded_year': 1999,
#   'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Sabre',
#   'founded_year': 1960,
#   'acquisition': {'price_amount': 4300000000}},
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
result = db.companies.find({'acquisition.acquired_year': {'$gt': 2015}},                     {
    "name": 1,
    "acquisition": 1,
    "_id": 0
}).sort([('acquisition.price_amount', 1)])

display(list(result))
# Out:
# []

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
result = db.companies.find({}, {
    "name": 1,
    "founded_year": 1,
    "_id": 0
}).sort([('founded_year', 1)])

#No lo imprimimos como lista porque devuelve error por consumo excesivo de memoria
display(result)

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
result = db.companies.find({'founded_day': {'$lte': 7}}, {
    "name": 1,
    "founded_day": 1,
    "acquisition.price_amount": 1,
    "_id": 0
}).sort([('acquisition.price_amount', -1)])

display(list(result))
# Out:
# [{'name': 'Netscape',
#   'founded_day': 4,
#   'acquisition': {'price_amount': 4200000000}},
#  {'name': 'PayPal',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1500000000}},
#  {'name': 'Zappos',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1200000000}},
#  {'name': 'Alibaba',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 1000000000}},
#  {'name': 'Postini',
#   'founded_day': 2,
#   'acquisition': {'price_amount': 625000000}},
#  {'name': 'Danger',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 500000000}},
#  {'name': 'Clearwell Systems',
#   'founded_day': 6,
#   'acquisition': {'price_amount': 410000000}},
#  {'name': 'PrimeSense',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 345000000}},
#  {'name': 'Amobee',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 321000000}},
#  {'name': 'BlueLithium',
#   'founded_day': 1,
#   'acquisition': {'price_amount': 300000000}},
#  {'name': 'Vitrue',
# ...

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
result = db.companies.find({'category_code': 'web', 'number_of_employees': {'$gt': 4000}}, {
    "name": 1,
    "category_code": 1,
    "number_of_employees": 1,
    "_id": 0
}).sort([('number_of_employees', 1)])

display(list(result))
# Out:
# [{'name': 'Expedia', 'category_code': 'web', 'number_of_employees': 4400},
#  {'name': 'AOL', 'category_code': 'web', 'number_of_employees': 8000},
#  {'name': 'Webkinz', 'category_code': 'web', 'number_of_employees': 8657},
#  {'name': 'Rakuten', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Los Angeles Times Media Group',
#   'category_code': 'web',
#   'number_of_employees': 10000},
#  {'name': 'Groupon', 'category_code': 'web', 'number_of_employees': 10000},
#  {'name': 'Yahoo!', 'category_code': 'web', 'number_of_employees': 13600},
#  {'name': 'eBay', 'category_code': 'web', 'number_of_employees': 15000},
#  {'name': 'Experian', 'category_code': 'web', 'number_of_employees': 15500}]

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
result = db.companies.find({'acquisition.price_currency_code': 'EUR', 'acquisition.price_amount': {'$gt': 10000000}}, {
    "name": 1,
    "acquisition.price_amount": 1,
    "acquisition.price_currency_code": 1,
    "_id": 0
})

display(list(result))
# Out:
# [{'name': 'ZYB',
#   'acquisition': {'price_amount': 31500000, 'price_currency_code': 'EUR'}},
#  {'name': 'Apertio',
#   'acquisition': {'price_amount': 140000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Greenfield Online',
#   'acquisition': {'price_amount': 40000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Webedia',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Wayfinder',
#   'acquisition': {'price_amount': 24000000, 'price_currency_code': 'EUR'}},
#  {'name': 'Tuenti Technologies',
#   'acquisition': {'price_amount': 70000000, 'price_currency_code': 'EUR'}},
#  {'name': 'BioMed Central',
#   'acquisition': {'price_amount': 43400000, 'price_currency_code': 'EUR'}}]

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
result = db.companies.find({'founded_month': {'$lte': 3}}, {
    "name": 1,
    "founded_month": 1,
    "acquisition.price_amount": 1,
    "_id": 0
}).limit(10)

display(list(result))
# Out:
# [{'name': 'Facebook', 'founded_month': 2},
#  {'name': 'Twitter', 'founded_month': 3},
#  {'name': 'StumbleUpon',
#   'founded_month': 2,
#   'acquisition': {'price_amount': 29000000}},
#  {'name': 'Gizmoz', 'founded_month': 1, 'acquisition': {'price_amount': None}},
#  {'name': 'Helio',
#   'founded_month': 2,
#   'acquisition': {'price_amount': 39000000}},
#  {'name': 'Babelgum', 'founded_month': 3},
#  {'name': 'Yahoo!', 'founded_month': 1},
#  {'name': 'Mahalo', 'founded_month': 3},
#  {'name': 'Meetup', 'founded_month': 1},
#  {'name': 'Jangl SMS', 'founded_month': 3}]

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
result = db.companies.find({'$and': 
    [
    {'founded_year': {'$gte': 2000}}, 
    {'founded_year': {'$lte': 2010}},
    {'acquisition.acquired_year': {"$not": {"$lt": 2011}}}
    ]
}, {
    "name": 1,
    "founded_year": 1,
    "acquisition.acquired_year": 1,
    "_id": 0
})             


display(list(result))
# Out:
# [{'name': 'Wetpaint',
#   'founded_year': 2005,
#   'acquisition': {'acquired_year': 2013}},
#  {'name': 'Zoho', 'founded_year': 2005},
#  {'name': 'Digg',
#   'founded_year': 2004,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Facebook', 'founded_year': 2004},
#  {'name': 'Omnidrive', 'founded_year': 2005},
#  {'name': 'Geni',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2012}},
#  {'name': 'Twitter', 'founded_year': 2006},
#  {'name': 'Scribd', 'founded_year': 2007},
#  {'name': 'Slacker', 'founded_year': 2006},
#  {'name': 'MeetMoi', 'founded_year': 2007},
#  {'name': 'Babelgum', 'founded_year': 2007},
#  {'name': 'Technorati', 'founded_year': 2002},
#  {'name': 'AddThis', 'founded_year': 2004},
#  {'name': 'OpenX', 'founded_year': 2008},
#  {'name': 'Mahalo', 'founded_year': 2007},
#  {'name': 'Sparter', 'founded_year': 2007},
#  {'name': 'Kyte',
#   'founded_year': 2006,
#   'acquisition': {'acquired_year': 2011}},
# ...
