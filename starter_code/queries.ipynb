# %% [markdown]
# ![Ironhack Logo](https://i.imgur.com/1QgrNNw.png)

# %%
from pymongo import MongoClient
client = MongoClient ('localhost', 27017)
db = client['companies']

# %% [markdown]
# # Answers
# ### 1. All the companies that it's name match 'Babelgum'. Retrieve only their `name` field.

# %%
data = {'name':'Babelgum'}
print(data['name'])
# Out:
# Babelgum

# %% [markdown]
# ### 2. All the companies that have more than 5000 employees. Limit the search to 20 companies and sort them by **number of employees**.

# %%
cursor = db.companies.find({"number_of_employees": {"$gt":5000}}).limit(20).sort("number_of_employees")
for i in cursor:
    print(i['name'], i['number_of_employees'])
# Out:
# Nintendo 5080
# Hexaware Technologies 5200
# Facebook 5299
# OpenText 5300
# LSI 5400
# CPM Braxis 5400
# Microchip Technologies 5500
# Mediaset 5729
# Mindray Medical International 5763
# Baidu 6000
# Dentsu 6000
# Tata Communications 6000
# Atmel 6000
# Acxiom 6200
# Acxiom 6200
# SRA International 6400
# Moody's 6800
# ManTech 7000
# Adobe Systems 7173
# Broadcom 7400

# %% [markdown]
# ### 3. All the companies founded between 2000 and 2005, both years included. Retrieve only the `name` and `founded_year` fileds.

# %%
founded = db.companies.find({'$and': [{'founded_year': {'$gte':2000} }, {'founded_year': {'$lte':2005} }]})

for i in founded:
    print(i['name'], i['founded_year'])
# Out:
# Zoho 2005
# Wetpaint 2005
# Omnidrive 2005
# Digg 2004
# Gizmoz 2003
# StumbleUpon 2002
# Helio 2005
# Facebook 2004
# Plaxo 2002
# Technorati 2002
# AddThis 2004
# Veoh 2004
# Jingle Networks 2005
# Meetup 2002
# Wesabe 2005
# LifeLock 2005
# Jangl SMS 2005
# SmugMug 2002
# Skype 2003
# Jajah 2005
# Pando Networks 2004
# YouTube 2005
# Ikan 2003
# delicious 2003
# Jobster 2004
# Topix 2002
# Revision3 2005
# AllPeers 2004
# iSkoot 2005
# Steorn 2000
# iContact 2003
# MeeVee 2000
# blinkx 2004
# ClipBlast! 2005
# Zlio 2005
# Yelp 2004
# AllofMP3 2000
# Coghead 2003
# Farecast 2003
# Dailymotion 2005
# RockYou 2005
# KickApps 2004
# Instructables 2005
# Slide 2005
# Swivel 2005
# Flickr 2004
# Bebo 2005
# Netvibes 2005
# TripHub 2005
# FeedBurner 2004
# Sway 2004
# CornerWorld 2002
# PBworks 2005
# adBrite 2003
# Meebo 2005
# Loomia 2004
# Newsvine 2005
# Jamendo 2005
# Dogster 2004
# iLike 2002
# Box 2005
# LinkedIn 2003
# Conduit 2005
# Kaboodle 2005
# TechnologyGuide 2001
# ...

# %% [markdown]
# ### 4. All the companies that had a Valuation Amount of more than 100.000.000 and have been founded before 2010. Retrieve only the `name` and `ipo` fields.

# %%
ipo = db.companies.find({'$and': [{'founded_year': {'$lt':2010} }, {'ipo.valuation_amount': {'$gt':100000000} }]})

for i in ipo:
    print(i['name'], i['ipo'])
# Out:
# Twitter {'valuation_amount': 18100000000, 'valuation_currency_code': 'USD', 'pub_year': 2013, 'pub_month': 11, 'pub_day': 7, 'stock_symbol': 'NYSE:TWTR'}
# Facebook {'valuation_amount': 104000000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 5, 'pub_day': 18, 'stock_symbol': 'NASDAQ:FB'}
# Yelp {'valuation_amount': 1300000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 3, 'pub_day': 2, 'stock_symbol': 'NYSE:YELP'}
# LinkedIn {'valuation_amount': 9310000000, 'valuation_currency_code': 'USD', 'pub_year': 2011, 'pub_month': 7, 'pub_day': 20, 'stock_symbol': 'NYSE:LNKD'}
# Brightcove {'valuation_amount': 290000000, 'valuation_currency_code': 'USD', 'pub_year': 2012, 'pub_month': 2, 'pub_day': 17, 'stock_symbol': 'NASDAQ:BCOV'}
# Amazon {'valuation_amount': 100000000000, 'valuation_currency_code': 'USD', 'pub_year': 1997, 'pub_month': 5, 'pub_day': None, 'stock_symbol': 'NASDAQ:AMZN'}
# ...

# %% [markdown]
# ### 5. All the companies that have less than 1000 employees and have been founded before 2005. Order them by the number of employees and limit the search to 10 companies.

# %%
f = db.companies.find({'$and': [{'number_of_employees': {'$lt':1000} }, {'founded_year': {'$lt':2005} }]}).limit(10).sort("number_of_employees", -1)

for i in f:
    print(i['name'], i['number_of_employees'])
# Out:
# Infinera Corporation 974
# NorthPoint Communications Group 948
# 888 Holdings 931
# Forrester Research 903
# SonicWALL 900
# Webmetrics 900
# Cornerstone OnDemand 881
# Yelp 800
# ZoomInfo 800
# MySpace 800

# %% [markdown]
# ### 6. All the companies that don't include the `partners` field.

# %%
g = db.companies.find({'partners': {'$exists': False}})

for i in g:
    print(i['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-aec8524f3c3f> in <module>
#       2
#       3 for i in g:
# ----> 4     print(i['name'])
#
# KeyError: 'name'

# %% [markdown]
# ### 7. All the companies that have a null type of value on the `category_code` field.

# %%
h = db.companies.find({'category_code': None })

for i in h:
    print(i['name'])
# Out:
# Collective
# Snimmer
# KoolIM
# Level9 Media
# VidKing
# Drigg
# SpaceTime
# MMDAYS
# Touch Clarity
# Inside Group
# Tapesh
# Repeater Store
# NewPersia
# iPersians
# Pyra Labs
# Feedmap
# NuvoMedia
# Intwine
# The Weinstein Company
# ExecuNet
# A1Vacations
# TripHomes
# Picturehouse
# Covalent Technologies
# Epic Trip
# Fidelity
# Quirk
# Leechblock
# Telepost
# Skyrove
# My Success Gateway
# The Easynet Group
# NetNames
# RealNames
# Sniperoo
# JD Project
# ABC News
# Teoma Technologies
# cometro
# U-Cast
# TechJuicer
# Fnatic
# Sports Gamer
# Infraworks
# MessageOne
# Idealab
# Invitastic
# Windows Live Events
# News Futures
# Foresight Exchange
# Greenspun
# American Solutions
# Media Run
# Tonic Studios
# USLegalForms
# Livevault
# Vector Capital
# Neudesic
# TuneCircle
# FatPort
# Excilan SA
# Hotbar
# eWeb Productions
# SEO Toolset
# ClarityBlue
# Reuters
# Guru
# Paxfire
# Digital-Telepathy
# Pidgin Technologies
# Time Lending California
# Gazprom-Media
# reQall
# Fon11
# ...

# %% [markdown]
# ### 8. All the companies that have at least 100 employees but less than 1000. Retrieve only the `name` and `number of employees` fields.

# %%
j = db.companies.find({'$and': [{'number_of_employees': {'$gte':100} }, {'number_of_employees': {'$lt':1000} }]})

for i in j:
    print(i['name'], i['number_of_employees'])
# Out:
# AdventNet 600
# AddThis 120
# OpenX 305
# LifeLock 644
# Jajah 110
# Livestream 120
# Ustream 250
# iContact 300
# Yelp 800
# Dailymotion 120
# RockYou 106
# Meebo 200
# Box 950
# Conduit 215
# Eventbrite 200
# Redfin 100
# oDesk 120
# Simply Hired 100
# Spreadshirt 230
# PhotoBox 600
# spigit 120
# Bazaarvoice 600
# hi5 100
# PowerReviews 120
# Tagged 162
# PayScale 130
# Truphone 450
# Hightail 200
# Nimbuzz 140
# Brightcove 220
# IMVU 150
# INgage Networks 100
# MobiTV 300
# Dropbox 350
# Jimdo 170
# KIT digital 200
# BlueLithium 135
# ZoomInfo 800
# Zango 225
# MySpace 800
# Trulia 500
# TechTarget 600
# TubeMogul 230
# Sportsline 264
# Espotting 250
# OpenTable 550
# airG 180
# Adknowledge 300
# ChannelAdvisor 300
# Ooyala 300
# hulu 153
# ZocDoc 450
# PubMatic 380
# Clickable 160
# mig33 100
# Mozilla 800
# Kaltura 160
# Moz 130
# Zillow 600
# Wamba 120
# Zimbra 200
# Fon 100
# Blurb 150
# The Climate Corporation 150
# Automattic 200
# uTest 120
# Payoneer 200
# EchoSign 100
# ...

# %% [markdown]
# ### 9. Order all the companies by their IPO price descendently.

# %%
k = db.companies.find({'ipo': {'$exists': True}}).limit(20).sort("ipo.valuation_amount", -1)

for i in k:
    print(i['name'])
# Out:
# GREE
# Facebook
# Amazon
# Twitter
# Groupon
# Tencent
# Western Digital
# LinkedIn
# BMC Software
# Rackspace
# Baidu
# TripAdvisor
# HomeAway
# Zillow
# Nielsen
# Yelp
# Chegg
# Chegg
# RPX Corporation
# Higher One

# %% [markdown]
# ### 10. Retrieve the 10 companies with more employees, order by the `number of employees`

# %%
l = db.companies.find({'number_of_employees': {'$exists': True}}).limit(10).sort("number_of_employees", -1)

for i in l:
    print(i['name'], i['number_of_employees'])
# Out:
# Siemens 405000
# IBM 388000
# Toyota 320000
# PayPal 300000
# Nippon Telegraph and Telephone Corporation 227000
# Samsung Electronics 221726
# Accenture 205000
# Tata Consultancy Services 200300
# Flextronics International 200000
# Safeway 186000

# %% [markdown]
# ### 11. All the companies founded on the second semester of the year. Limit your search to 1000 companies.

# %%
m = db.companies.find({'$and': [{'founded_month': {'$gte':7} }, {'founded_month': {'$lte':12} }]}).limit(1000)

for i in m:
    print(i['name'], e['founded_month'])
# Out:
# Zoho 10
# Wetpaint 10
# Omnidrive 10
# Digg 10
# Joost 10
# Plaxo 10
# eBay 10
# Powerset 10
# Kyte 10
# Thoof 10
# Jingle Networks 10
# Wesabe 10
# LifeLock 10
# SmugMug 10
# Skype 10
# Pando Networks 10
# Ikan 10
# delicious 10
# AllPeers 10
# Wize 10
# Google 10
# SellABand 10
# iContact 10
# MeeVee 10
# blinkx 10
# Zlio 10
# Jaiku 10
# Yelp 10
# Yapta 10
# Fleck 10
# SideStep 10
# RockYou 10
# Instructables 10
# Slide 10
# Swivel 10
# Netvibes 10
# CrowdVine 10
# TheFind 10
# Sway 10
# CornerWorld 10
# FlickIM 10
# Terabitz 10
# Kaboodle 10
# Go2Web20 10
# GigaOM 10
# TechnologyGuide 10
# Redfin 10
# Techmeme 10
# Wink 10
# Recipezaar 10
# Ujogo 10
# stylediary 10
# Gumiyo 10
# Cyworld 10
# Piczo 10
# Socialtext 10
# ConnectMeAnywhere 10
# Clipperz 10
# hi5 10
# Tagged 10
# Nintendo 10
# Indeed 10
# ONEsite 10
# Cerado 10
# Wallhogs 10
# Grockit 10
# eBuddy 10
# Jaxtr 10
# JumpBox 10
# Phonezoo 10
# LongJump 10
# Relationals 10
# Wishpot 10
# Forbes 10
# Boonex 10
# ...

# %% [markdown]
# ### 12. All the companies that have been 'deadpooled' after the third year.

# %% [markdown]
# ### 13. All the companies founded before 2000 that have and acquisition amount of more than 10.000.000

# %%
n = db.companies.find({'$and': [{'founded_year': {'$lt':2000} }, {'acquisition.price_amount': {'$gt':10000000} }]})

for i in n:
    print(i['name'])
# Out:
# Postini
# SideStep
# Recipezaar
# PayPal
# Snapfish
# Neopets
# Sun Microsystems
# Zappos
# Alibaba
# Lastminute
# Sabre
# Sportsline
# Webshots
# MIVA
# Digitas
# iVillage
# PriceGrabber
# LinkShare
# Kaboose
# Fastclick
# Eloqua
# Omniture
# Interwoven
# HowStuffWorks
# RealAge
# Match
# Xdrive
# Alexa
# Offermatica
# ioko
# MyNewPlace
# DoubleClick
# Danger
# Direct Hit
# BEA Systems
# Napster
# SafeNet
# LowerMyBills
# Various
# aQuantive
# PeopleSupport
# Wedding Channel
# iCrossing
# Responsys
# Homestead Technologies
# Phoenix Technologies
# GlobalEnglish
# Macromedia
# PGP Corporation
# Iomega
# BizRate
# MessageLabs
# Gracenote
# Razorfish
# Sonic Solutions
# Siebel Systems
# Aprimo
# Opsware
# Netscape
# Vignette
# Blue Coat Systems
# Ars Technica
# LSI
# VMware
# OpenAir
# mindSHIFT Technologies
# InsureMe
# SwapDrive
# Marvel Entertainment
# CyberCoders
# Channel Intelligence
# Q-go
# Xerox
# Speedera Networks
# eBaum's World
# Audible
# Extend Media
# ...

# %% [markdown]
# ### 14. All the companies that have been acquired after 2015, order by the acquisition amount, and retrieve only their `name` and `acquisiton` field.

# %%
o = db.companies.find({'$and': [{'acquisition.acquired_year': {'$gt':2015} }]}).sort("acquisition.price_amount", -1)

for i in o:
    print(i['name'])

# %% [markdown]
# ### 15. Order the companies by their `founded year`, retrieving only their `name` and `founded year`.

# %%
p = db.companies.find({'founded_year': {'$exists': True}}).limit(10).sort("founded_year", -1)

for i in p:
    print(i['name'], i['founded_year'])
# Out:
# Fixya 2013
# Wamba 2013
# Advaliant 2013
# Fluc 2013
# iBazar 2013
# Gimigo 2013
# SEOGroup 2013
# Clowdy 2013
# WhosCall 2013
# Pikk 2013

# %% [markdown]
# ### 16. All the companies that have been founded on the first seven days of the month, including the seventh. Sort them by their `aquisition price` descendently. Limit the search to 10 documents.

# %%
q = db.companies.find({'founded_day': {'$lte':7}}).limit(10).sort("acquisition.price_amount", -1)

for i in q:
    print(i['name'], i['founded_day'])
# Out:
# Netscape 4
# PayPal 1
# Zappos 1
# Alibaba 1
# Postini 2
# Danger 1
# Clearwell Systems 6
# PrimeSense 1
# Amobee 1
# BlueLithium 1

# %% [markdown]
# ### 17. All the companies on the 'web' `category` that have more than 4000 employees. Sort them by the amount of employees in ascendant order.

# %%
r = db.companies.find({'$and': [{'category_code':'web'}, {'number_of_employees': {'$gt':4000}}]}).limit(10).sort("number_of_employees")

for i in r:
    print(i['name'])
# Out:
# Expedia
# AOL
# Webkinz
# Rakuten
# Los Angeles Times Media Group
# Groupon
# Yahoo!
# eBay
# Experian

# %% [markdown]
# ### 18. All the companies which their acquisition amount is more than 10.000.000, and currency are 'EUR'.

# %%
s = db.companies.find({'$and': [{'acquisition.price_currency_code':'EUR'}, {'acquisition.price_amount': {'$gt':10000000}}]})

for i in s:
    print(i['name'])
# Out:
# ZYB
# Apertio
# Greenfield Online
# Webedia
# Wayfinder
# Tuenti Technologies
# BioMed Central

# %% [markdown]
# ### 19. All the companies that have been acquired on the first trimester of the year. Limit the search to 10 companies, and retrieve only their `name` and `acquisition` fields.

# %%
t = db.companies.find({'$and': [{'acquisition.acquired_month': {'$lte':3}}, {'acquisition': {'$exists': True}}]}).limit(10)

for i in t:
    print(i['name'], i['acquisition'])
# Out:
# Kyte {'price_amount': None, 'price_currency_code': 'USD', 'term_code': None, 'source_url': 'http://techcrunch.com/2011/01/31/exclusive-kit-digital-acquires-kickapps-kewego-and-kyte-for-77-2-million/', 'source_description': 'KIT digital Acquires KickApps, Kewego AND Kyte For $77.2 Million', 'acquired_year': 2011, 'acquired_month': 1, 'acquired_day': 31, 'acquiring_company': {'name': 'KIT digital', 'permalink': 'kit-digital'}}
# NetRatings {'price_amount': 327000000, 'price_currency_code': 'USD', 'term_code': 'cash', 'source_url': 'http://login.vnuemedia.com/hr/login/login_subscribe.jsp?id=0oqDem1gYIfIclz9i2%2Ffqj5NxCp2AC5DPbVnyT2da8GyV2mXjasabE128n69OrmcAh52%2FGE3pSG%2F%0AEKRYD9vh9EhrJrxukmUzh532fSMTZXL42gwPB80UWVtF1NwJ5UZSM%2BCkLU1mpYBoHFgiH%2Fi0f6Ax%0A9yMIVxt47t%2BHamhEQ0nkOEK24L', 'source_description': 'Nielsen buys rest of NetRatings', 'acquired_year': 2007, 'acquired_month': 2, 'acquired_day': None, 'acquiring_company': {'name': 'Nielsen', 'permalink': 'nielsen'}}
# ...

# %% [markdown]
# ### 20. All the companies that have been founded between 2000 and 2010, but have not been acquired before 2011.

# %%
u = db.companies.find({'$and': [{'founded_year': {'$gte':2000} }, {'founded_year': {'$lte':2010} }, {'acquisition.acquired_year': {'$gt':2011} }]}) 

for i in u:
    print(i['name'])
# Out:
# Wetpaint
# Digg
# Geni
# blogTV
# Revision3
# iContact
# Mashery
# Dailymotion
# KickApps
# Netvibes
# adBrite
# Meebo
# Seesmic
# Oodle
# Indeed
# Grockit
# Zenfolio
# Wishpot
# Retrevo
# SelectMinds
# TokBox
# Docstoc
# sezmi
# LocaModa
# OMGPOP
# Daylife
# Behance
# Attributor
# Viewdle
# Clickable
# Xobni
# Sermo
# Worklight
# Zimbra
# earthmine
# CondoDomain
# Whiskey Media
# Uptake
# The Climate Corporation
# AdReady
# Tumblr
# Rollbase
# JackBe
# Marakana
# Vitrue
# Peer39
# Loopt
# Mogreet
# UpNext
# TrustedID
# SocialPicks
# Shipwire
# Goodreads
# KAYAK
# Meraki
# Jobfox
# Livemocha
# Outspark
# SuccessFactors
# Amobee
# Taptu
# BreakingPoint Systems
# Qype
# MOG
# SnapNames
# Paprika Lab
# Camlink
# Particle
# PacketFront
# Star Analytics
# Replay Solutions
# SignalDemand
# Planypus
# Snipshot
# OrangeSoda
# Trendrr
# Weplay
# Vivity Labs
# MediaWhiz
# mediaFORGE
# Trunkt
# Compfight
# Salesconx
# Collective Intellect
# EQAL
# LOVEFiLM
# TeachStreet
# Mollom
# Android
# ...
